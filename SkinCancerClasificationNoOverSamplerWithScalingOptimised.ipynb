# %% [markdown]
# # **SkinCancerClasification - No OverSampler With Scaling And Optimised**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
# Sklearn scaling
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction (Without Scaling and One Hot Encoding)**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (8012, 2352)
# Testing Shape: (2003, 2352)

# %% [markdown]
# ### **Scaling and Normalization**

# %%
# Next, we normalize our training data to be between 0 and 1
scaler = MinMaxScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### **Create Sequential Model with 64 units**

# %%
# Increased units to 100
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 246107 (961.36 KB)
# Trainable params: 246107 (961.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased Epoch to 50
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=50,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/50
# 251/251 - 3s - loss: 1.0898 - accuracy: 0.6620 - 3s/epoch - 12ms/step
# Epoch 2/50
# 251/251 - 2s - loss: 0.9768 - accuracy: 0.6741 - 2s/epoch - 8ms/step
# Epoch 3/50
# 251/251 - 2s - loss: 0.9412 - accuracy: 0.6731 - 2s/epoch - 9ms/step
# Epoch 4/50
# 251/251 - 2s - loss: 0.9281 - accuracy: 0.6776 - 2s/epoch - 7ms/step
# Epoch 5/50
# 251/251 - 2s - loss: 0.9132 - accuracy: 0.6795 - 2s/epoch - 6ms/step
# Epoch 6/50
# 251/251 - 2s - loss: 0.8943 - accuracy: 0.6835 - 2s/epoch - 6ms/step
# Epoch 7/50
# 251/251 - 2s - loss: 0.8902 - accuracy: 0.6858 - 2s/epoch - 6ms/step
# Epoch 8/50
# 251/251 - 2s - loss: 0.8787 - accuracy: 0.6861 - 2s/epoch - 6ms/step
# Epoch 9/50
# 251/251 - 1s - loss: 0.8651 - accuracy: 0.6911 - 1s/epoch - 5ms/step
# Epoch 10/50
# 251/251 - 1s - loss: 0.8564 - accuracy: 0.6908 - 870ms/epoch - 3ms/step
# Epoch 11/50
# 251/251 - 1s - loss: 0.8560 - accuracy: 0.6928 - 1s/epoch - 5ms/step
# Epoch 12/50
# 251/251 - 1s - loss: 0.8615 - accuracy: 0.6920 - 1s/epoch - 6ms/step
# Epoch 13/50
# 251/251 - 1s - loss: 0.8490 - accuracy: 0.6972 - 1s/epoch - 5ms/step
# Epoch 14/50
# 251/251 - 1s - loss: 0.8527 - accuracy: 0.6967 - 890ms/epoch - 4ms/step
# Epoch 15/50
# 251/251 - 1s - loss: 0.8411 - accuracy: 0.6983 - 855ms/epoch - 3ms/step
# Epoch 16/50
# 251/251 - 1s - loss: 0.8403 - accuracy: 0.6983 - 875ms/epoch - 3ms/step
# Epoch 17/50
# 251/251 - 1s - loss: 0.8318 - accuracy: 0.7014 - 865ms/epoch - 3ms/step
# Epoch 18/50
# 251/251 - 1s - loss: 0.8287 - accuracy: 0.7031 - 876ms/epoch - 3ms/step
# Epoch 19/50
# 251/251 - 1s - loss: 0.8245 - accuracy: 0.7048 - 874ms/epoch - 3ms/step
# Epoch 20/50
# 251/251 - 1s - loss: 0.8335 - accuracy: 0.7063 - 865ms/epoch - 3ms/step
# Epoch 21/50
# 251/251 - 1s - loss: 0.8270 - accuracy: 0.7026 - 868ms/epoch - 3ms/step
# Epoch 22/50
# 251/251 - 1s - loss: 0.8216 - accuracy: 0.7016 - 849ms/epoch - 3ms/step
# Epoch 23/50
# 251/251 - 1s - loss: 0.8178 - accuracy: 0.7059 - 887ms/epoch - 4ms/step
# Epoch 24/50
# 251/251 - 1s - loss: 0.8114 - accuracy: 0.7071 - 862ms/epoch - 3ms/step
# Epoch 25/50
# 251/251 - 1s - loss: 0.8082 - accuracy: 0.7121 - 1s/epoch - 5ms/step
# Epoch 26/50
# 251/251 - 1s - loss: 0.8096 - accuracy: 0.7081 - 1s/epoch - 5ms/step
# Epoch 27/50
# 251/251 - 1s - loss: 0.8031 - accuracy: 0.7103 - 1s/epoch - 5ms/step
# Epoch 28/50
# 251/251 - 1s - loss: 0.8002 - accuracy: 0.7143 - 866ms/epoch - 3ms/step
# Epoch 29/50
# 251/251 - 1s - loss: 0.7940 - accuracy: 0.7131 - 863ms/epoch - 3ms/step
# Epoch 30/50
# 251/251 - 1s - loss: 0.7897 - accuracy: 0.7151 - 853ms/epoch - 3ms/step
# Epoch 31/50
# 251/251 - 1s - loss: 0.7941 - accuracy: 0.7122 - 867ms/epoch - 3ms/step
# Epoch 32/50
# 251/251 - 1s - loss: 0.7940 - accuracy: 0.7102 - 871ms/epoch - 3ms/step
# Epoch 33/50
# 251/251 - 1s - loss: 0.7834 - accuracy: 0.7156 - 844ms/epoch - 3ms/step
# Epoch 34/50
# 251/251 - 1s - loss: 0.7892 - accuracy: 0.7126 - 844ms/epoch - 3ms/step
# Epoch 35/50
# 251/251 - 1s - loss: 0.7766 - accuracy: 0.7172 - 870ms/epoch - 3ms/step
# Epoch 36/50
# 251/251 - 1s - loss: 0.7774 - accuracy: 0.7151 - 874ms/epoch - 3ms/step
# Epoch 37/50
# 251/251 - 1s - loss: 0.7795 - accuracy: 0.7138 - 864ms/epoch - 3ms/step
# Epoch 38/50
# 251/251 - 1s - loss: 0.7657 - accuracy: 0.7197 - 872ms/epoch - 3ms/step
# Epoch 39/50
# 251/251 - 1s - loss: 0.7617 - accuracy: 0.7173 - 1s/epoch - 5ms/step
# Epoch 40/50
# 251/251 - 1s - loss: 0.7594 - accuracy: 0.7237 - 1s/epoch - 6ms/step
# Epoch 41/50
# 251/251 - 1s - loss: 0.7659 - accuracy: 0.7243 - 1s/epoch - 4ms/step
# Epoch 42/50
# 251/251 - 1s - loss: 0.7556 - accuracy: 0.7235 - 848ms/epoch - 3ms/step
# Epoch 43/50
# 251/251 - 1s - loss: 0.7680 - accuracy: 0.7183 - 854ms/epoch - 3ms/step
# Epoch 44/50
# 251/251 - 1s - loss: 0.7558 - accuracy: 0.7209 - 844ms/epoch - 3ms/step
# Epoch 45/50
# 251/251 - 1s - loss: 0.7575 - accuracy: 0.7198 - 861ms/epoch - 3ms/step
# Epoch 46/50
# 251/251 - 1s - loss: 0.7458 - accuracy: 0.7257 - 878ms/epoch - 3ms/step
# Epoch 47/50
# 251/251 - 1s - loss: 0.7490 - accuracy: 0.7227 - 849ms/epoch - 3ms/step
# Epoch 48/50
# 251/251 - 1s - loss: 0.7424 - accuracy: 0.7277 - 886ms/epoch - 4ms/step
# Epoch 49/50
# 251/251 - 1s - loss: 0.7393 - accuracy: 0.7268 - 873ms/epoch - 3ms/step
# Epoch 50/50
# 251/251 - 1s - loss: 0.7468 - accuracy: 0.7250 - 883ms/epoch - 4ms/step

# %%
# Evaluate the model using the training data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 63/63 - 0s - loss: 0.8246 - accuracy: 0.7054 - 255ms/epoch - 4ms/step
# Loss: 0.8246379494667053, Accuracy: 0.7054418325424194

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
print(y_true)
print(y_pred)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# [4 4 4 ... 4 2 4]
# [4 4 4 ... 4 4 4]

# %%
pred=model.predict(X_test)
pred
# Out:
# 63/63 [==============================] - 0s 2ms/step
# array([[3.4043626e-03, 8.5349858e-04, 1.4916778e-02, ..., 9.7415686e-01,
#         1.3483205e-04, 2.4594651e-03],
#        [1.3008677e-02, 2.5076398e-03, 2.7604843e-02, ..., 9.0807456e-01,
#         4.8977323e-04, 4.1760732e-03],
#        [9.7220438e-03, 4.1640326e-03, 1.1925798e-02, ..., 9.1627169e-01,
#         4.8462492e-03, 1.3282998e-03],
#        ...,
#        [1.5407974e-03, 1.4694591e-02, 1.1412018e-01, ..., 7.3003703e-01,
#         5.5249542e-02, 8.0792278e-02],
#        [1.8861486e-02, 5.1779274e-02, 1.4951602e-01, ..., 6.4176494e-01,
#         3.1070089e-02, 9.3834385e-02],
#        [2.4849403e-04, 3.1391147e-03, 2.4459822e-02, ..., 9.0887243e-01,
#         1.6000694e-02, 4.6956263e-02]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.27      0.34      0.30        61
#          bcc       0.43      0.55      0.49        96
#          bkl       0.42      0.27      0.33       228
#           df       0.00      0.00      0.00        37
#           nv       0.79      0.93      0.86      1327
#         vasc       0.47      0.28      0.35        32
#          mel       0.44      0.16      0.23       222
#
#     accuracy                           0.71      2003
#    macro avg       0.41      0.36      0.37      2003
# weighted avg       0.66      0.71      0.67      2003

# %%
confusion_matrix(y_true, y_pred)
# Out:
# array([[  21,   12,    5,    1,   17,    0,    5],
#        [   7,   53,    5,    0,   25,    4,    2],
#        [  20,   19,   61,    0,  117,    0,   11],
#        [  10,   11,    5,    0,   10,    0,    1],
#        [   6,   22,   38,    0, 1234,    3,   24],
#        [   5,    2,    2,    0,   13,    9,    1],
#        [   9,    3,   28,    1,  143,    3,   35]])

# %%
# Grab just one data point to test with
# test = np.expand_dims(X_train[0], axis=0)
# test.shape

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationNoOverSamplerWithScalingOptimised.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationNoOverSamplerWithScalingOptimised.h5")
