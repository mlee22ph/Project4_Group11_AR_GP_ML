# %% [markdown]
# # **SkinCancerClasification - With Scaling and more Optimisations**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
# Sklearn scaling
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Use RandomOverSampler**

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
x = np.array(x).reshape(-1,28,28,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 28, 28, 3)

# %%
print('Shape of Y :',y.shape)
# Out:
# Shape of Y : (46935,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
X_train.shape
# Out:
# (37548, 28, 28, 3)

# %%
# We want to flatten our image of 28x28 pixels to a 1D array of 784 pixels
ndims = X_train.shape[1] * X_train.shape[2] * X_train.shape[3]
X_train = X_train.reshape(X_train.shape[0], ndims)
X_test = X_test.reshape(X_test.shape[0], ndims)
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (37548, 2352)
# Testing Shape: (9387, 2352)

# %% [markdown]
# ### **Scaling and Normalization**

# %%
# Next, we normalize our training data to be between 0 and 1
scaler = MinMaxScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### **Create Sequential Model**

# %% [markdown]
# **With 64 units:**
#
# 294/294 - 1s - loss: 0.9814 - accuracy: 0.6068 - 926ms/epoch - 3ms/step
# Loss: 0.9813539981842041, Accuracy: 0.6067966222763062

# %%
# Increased units from previous try
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 246107 (961.36 KB)
# Trainable params: 246107 (961.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased epochs to 100
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 1174/1174 - 6s - loss: 1.6337 - accuracy: 0.3550 - 6s/epoch - 5ms/step
# Epoch 2/100
# 1174/1174 - 6s - loss: 1.3746 - accuracy: 0.4644 - 6s/epoch - 5ms/step
# Epoch 3/100
# 1174/1174 - 6s - loss: 1.2507 - accuracy: 0.5174 - 6s/epoch - 5ms/step
# Epoch 4/100
# 1174/1174 - 6s - loss: 1.1642 - accuracy: 0.5525 - 6s/epoch - 5ms/step
# Epoch 5/100
# 1174/1174 - 6s - loss: 1.0963 - accuracy: 0.5815 - 6s/epoch - 5ms/step
# Epoch 6/100
# 1174/1174 - 5s - loss: 1.0277 - accuracy: 0.6088 - 5s/epoch - 4ms/step
# Epoch 7/100
# 1174/1174 - 7s - loss: 0.9838 - accuracy: 0.6259 - 7s/epoch - 6ms/step
# Epoch 8/100
# 1174/1174 - 5s - loss: 0.9356 - accuracy: 0.6464 - 5s/epoch - 4ms/step
# Epoch 9/100
# 1174/1174 - 7s - loss: 0.8901 - accuracy: 0.6635 - 7s/epoch - 6ms/step
# Epoch 10/100
# 1174/1174 - 5s - loss: 0.8435 - accuracy: 0.6832 - 5s/epoch - 4ms/step
# Epoch 11/100
# 1174/1174 - 7s - loss: 0.8121 - accuracy: 0.6943 - 7s/epoch - 6ms/step
# Epoch 12/100
# 1174/1174 - 5s - loss: 0.7843 - accuracy: 0.7057 - 5s/epoch - 4ms/step
# Epoch 13/100
# 1174/1174 - 5s - loss: 0.7710 - accuracy: 0.7119 - 5s/epoch - 4ms/step
# Epoch 14/100
# 1174/1174 - 7s - loss: 0.7252 - accuracy: 0.7312 - 7s/epoch - 6ms/step
# Epoch 15/100
# 1174/1174 - 5s - loss: 0.7092 - accuracy: 0.7349 - 5s/epoch - 4ms/step
# Epoch 16/100
# 1174/1174 - 6s - loss: 0.6877 - accuracy: 0.7449 - 6s/epoch - 6ms/step
# Epoch 17/100
# 1174/1174 - 6s - loss: 0.6683 - accuracy: 0.7516 - 6s/epoch - 5ms/step
# Epoch 18/100
# 1174/1174 - 6s - loss: 0.6630 - accuracy: 0.7558 - 6s/epoch - 5ms/step
# Epoch 19/100
# 1174/1174 - 5s - loss: 0.6486 - accuracy: 0.7587 - 5s/epoch - 4ms/step
# Epoch 20/100
# 1174/1174 - 5s - loss: 0.6186 - accuracy: 0.7703 - 5s/epoch - 4ms/step
# Epoch 21/100
# 1174/1174 - 6s - loss: 0.6032 - accuracy: 0.7759 - 6s/epoch - 5ms/step
# Epoch 22/100
# 1174/1174 - 5s - loss: 0.5928 - accuracy: 0.7804 - 5s/epoch - 4ms/step
# Epoch 23/100
# 1174/1174 - 6s - loss: 0.5863 - accuracy: 0.7832 - 6s/epoch - 6ms/step
# Epoch 24/100
# 1174/1174 - 5s - loss: 0.5855 - accuracy: 0.7816 - 5s/epoch - 4ms/step
# Epoch 25/100
# 1174/1174 - 6s - loss: 0.5592 - accuracy: 0.7935 - 6s/epoch - 5ms/step
# Epoch 26/100
# 1174/1174 - 6s - loss: 0.5477 - accuracy: 0.7973 - 6s/epoch - 5ms/step
# Epoch 27/100
# 1174/1174 - 6s - loss: 0.5468 - accuracy: 0.7974 - 6s/epoch - 5ms/step
# Epoch 28/100
# 1174/1174 - 5s - loss: 0.5332 - accuracy: 0.8024 - 5s/epoch - 5ms/step
# Epoch 29/100
# 1174/1174 - 5s - loss: 0.5204 - accuracy: 0.8061 - 5s/epoch - 5ms/step
# Epoch 30/100
# 1174/1174 - 6s - loss: 0.5278 - accuracy: 0.8076 - 6s/epoch - 5ms/step
# Epoch 31/100
# 1174/1174 - 5s - loss: 0.4988 - accuracy: 0.8151 - 5s/epoch - 4ms/step
# Epoch 32/100
# 1174/1174 - 6s - loss: 0.5006 - accuracy: 0.8139 - 6s/epoch - 5ms/step
# Epoch 33/100
# 1174/1174 - 5s - loss: 0.5141 - accuracy: 0.8106 - 5s/epoch - 5ms/step
# Epoch 34/100
# 1174/1174 - 6s - loss: 0.5028 - accuracy: 0.8131 - 6s/epoch - 5ms/step
# Epoch 35/100
# 1174/1174 - 6s - loss: 0.4796 - accuracy: 0.8228 - 6s/epoch - 5ms/step
# Epoch 36/100
# 1174/1174 - 6s - loss: 0.4786 - accuracy: 0.8223 - 6s/epoch - 5ms/step
# Epoch 37/100
# 1174/1174 - 8s - loss: 0.4651 - accuracy: 0.8269 - 8s/epoch - 7ms/step
# Epoch 38/100
# 1174/1174 - 10s - loss: 0.4696 - accuracy: 0.8266 - 10s/epoch - 9ms/step
# Epoch 39/100
# 1174/1174 - 10s - loss: 0.4610 - accuracy: 0.8297 - 10s/epoch - 8ms/step
# Epoch 40/100
# 1174/1174 - 9s - loss: 0.4531 - accuracy: 0.8324 - 9s/epoch - 8ms/step
# Epoch 41/100
# 1174/1174 - 10s - loss: 0.4495 - accuracy: 0.8327 - 10s/epoch - 8ms/step
# Epoch 42/100
# 1174/1174 - 5s - loss: 0.4568 - accuracy: 0.8306 - 5s/epoch - 5ms/step
# Epoch 43/100
# 1174/1174 - 6s - loss: 0.4311 - accuracy: 0.8408 - 6s/epoch - 5ms/step
# Epoch 44/100
# 1174/1174 - 5s - loss: 0.4396 - accuracy: 0.8377 - 5s/epoch - 4ms/step
# Epoch 45/100
# 1174/1174 - 6s - loss: 0.4298 - accuracy: 0.8414 - 6s/epoch - 5ms/step
# Epoch 46/100
# 1174/1174 - 5s - loss: 0.4398 - accuracy: 0.8384 - 5s/epoch - 5ms/step
# Epoch 47/100
# 1174/1174 - 6s - loss: 0.4352 - accuracy: 0.8387 - 6s/epoch - 5ms/step
# Epoch 48/100
# 1174/1174 - 6s - loss: 0.4094 - accuracy: 0.8490 - 6s/epoch - 5ms/step
# Epoch 49/100
# 1174/1174 - 6s - loss: 0.4098 - accuracy: 0.8498 - 6s/epoch - 5ms/step
# Epoch 50/100
# 1174/1174 - 7s - loss: 0.4205 - accuracy: 0.8463 - 7s/epoch - 6ms/step
# Epoch 51/100
# 1174/1174 - 6s - loss: 0.4097 - accuracy: 0.8495 - 6s/epoch - 6ms/step
# Epoch 52/100
# 1174/1174 - 6s - loss: 0.4026 - accuracy: 0.8512 - 6s/epoch - 5ms/step
# Epoch 53/100
# 1174/1174 - 7s - loss: 0.4050 - accuracy: 0.8514 - 7s/epoch - 6ms/step
# Epoch 54/100
# 1174/1174 - 7s - loss: 0.3903 - accuracy: 0.8550 - 7s/epoch - 6ms/step
# Epoch 55/100
# 1174/1174 - 6s - loss: 0.3909 - accuracy: 0.8563 - 6s/epoch - 5ms/step
# Epoch 56/100
# 1174/1174 - 6s - loss: 0.3993 - accuracy: 0.8550 - 6s/epoch - 5ms/step
# Epoch 57/100
# 1174/1174 - 5s - loss: 0.3856 - accuracy: 0.8594 - 5s/epoch - 4ms/step
# Epoch 58/100
# 1174/1174 - 7s - loss: 0.3983 - accuracy: 0.8543 - 7s/epoch - 6ms/step
# Epoch 59/100
# 1174/1174 - 6s - loss: 0.3796 - accuracy: 0.8610 - 6s/epoch - 5ms/step
# Epoch 60/100
# 1174/1174 - 6s - loss: 0.3837 - accuracy: 0.8605 - 6s/epoch - 5ms/step
# Epoch 61/100
# 1174/1174 - 5s - loss: 0.3850 - accuracy: 0.8587 - 5s/epoch - 4ms/step
# Epoch 62/100
# 1174/1174 - 7s - loss: 0.3845 - accuracy: 0.8566 - 7s/epoch - 6ms/step
# Epoch 63/100
# 1174/1174 - 5s - loss: 0.3774 - accuracy: 0.8617 - 5s/epoch - 4ms/step
# Epoch 64/100
# 1174/1174 - 5s - loss: 0.3565 - accuracy: 0.8693 - 5s/epoch - 5ms/step
# Epoch 65/100
# 1174/1174 - 6s - loss: 0.3596 - accuracy: 0.8657 - 6s/epoch - 5ms/step
# Epoch 66/100
# 1174/1174 - 6s - loss: 0.3801 - accuracy: 0.8605 - 6s/epoch - 5ms/step
# Epoch 67/100
# 1174/1174 - 7s - loss: 0.3802 - accuracy: 0.8616 - 7s/epoch - 6ms/step
# Epoch 68/100
# 1174/1174 - 5s - loss: 0.3462 - accuracy: 0.8718 - 5s/epoch - 4ms/step
# Epoch 69/100
# 1174/1174 - 7s - loss: 0.3631 - accuracy: 0.8659 - 7s/epoch - 6ms/step
# Epoch 70/100
# 1174/1174 - 5s - loss: 0.3605 - accuracy: 0.8689 - 5s/epoch - 4ms/step
# Epoch 71/100
# 1174/1174 - 6s - loss: 0.3467 - accuracy: 0.8717 - 6s/epoch - 5ms/step
# Epoch 72/100
# 1174/1174 - 6s - loss: 0.3645 - accuracy: 0.8666 - 6s/epoch - 5ms/step
# Epoch 73/100
# 1174/1174 - 5s - loss: 0.3429 - accuracy: 0.8731 - 5s/epoch - 4ms/step
# Epoch 74/100
# 1174/1174 - 7s - loss: 0.3634 - accuracy: 0.8660 - 7s/epoch - 6ms/step
# Epoch 75/100
# 1174/1174 - 5s - loss: 0.3603 - accuracy: 0.8691 - 5s/epoch - 4ms/step
# Epoch 76/100
# 1174/1174 - 7s - loss: 0.3361 - accuracy: 0.8762 - 7s/epoch - 6ms/step
# Epoch 77/100
# 1174/1174 - 5s - loss: 0.3513 - accuracy: 0.8713 - 5s/epoch - 5ms/step
# Epoch 78/100
# 1174/1174 - 7s - loss: 0.3509 - accuracy: 0.8721 - 7s/epoch - 6ms/step
# Epoch 79/100
# 1174/1174 - 5s - loss: 0.3416 - accuracy: 0.8737 - 5s/epoch - 4ms/step
# Epoch 80/100
# 1174/1174 - 6s - loss: 0.3510 - accuracy: 0.8722 - 6s/epoch - 5ms/step
# Epoch 81/100
# 1174/1174 - 6s - loss: 0.3335 - accuracy: 0.8777 - 6s/epoch - 5ms/step
# Epoch 82/100
# 1174/1174 - 6s - loss: 0.3351 - accuracy: 0.8759 - 6s/epoch - 5ms/step
# Epoch 83/100
# 1174/1174 - 7s - loss: 0.3519 - accuracy: 0.8708 - 7s/epoch - 6ms/step
# Epoch 84/100
# 1174/1174 - 5s - loss: 0.3330 - accuracy: 0.8782 - 5s/epoch - 5ms/step
# Epoch 85/100
# 1174/1174 - 6s - loss: 0.3376 - accuracy: 0.8773 - 6s/epoch - 6ms/step
# Epoch 86/100
# 1174/1174 - 5s - loss: 0.3161 - accuracy: 0.8842 - 5s/epoch - 4ms/step
# Epoch 87/100
# 1174/1174 - 6s - loss: 0.3231 - accuracy: 0.8810 - 6s/epoch - 5ms/step
# Epoch 88/100
# 1174/1174 - 6s - loss: 0.3145 - accuracy: 0.8841 - 6s/epoch - 5ms/step
# Epoch 89/100
# 1174/1174 - 7s - loss: 0.3096 - accuracy: 0.8863 - 7s/epoch - 6ms/step
# Epoch 90/100
# 1174/1174 - 5s - loss: 0.3224 - accuracy: 0.8811 - 5s/epoch - 4ms/step
# Epoch 91/100
# 1174/1174 - 5s - loss: 0.3215 - accuracy: 0.8826 - 5s/epoch - 5ms/step
# Epoch 92/100
# 1174/1174 - 6s - loss: 0.3428 - accuracy: 0.8744 - 6s/epoch - 5ms/step
# Epoch 93/100
# 1174/1174 - 5s - loss: 0.3301 - accuracy: 0.8798 - 5s/epoch - 4ms/step
# Epoch 94/100
# 1174/1174 - 7s - loss: 0.3076 - accuracy: 0.8863 - 7s/epoch - 6ms/step
# Epoch 95/100
# 1174/1174 - 6s - loss: 0.3232 - accuracy: 0.8821 - 6s/epoch - 5ms/step
# Epoch 96/100
# 1174/1174 - 6s - loss: 0.3086 - accuracy: 0.8877 - 6s/epoch - 5ms/step
# Epoch 97/100
# 1174/1174 - 5s - loss: 0.3166 - accuracy: 0.8836 - 5s/epoch - 4ms/step
# Epoch 98/100
# 1174/1174 - 6s - loss: 0.3055 - accuracy: 0.8888 - 6s/epoch - 5ms/step
# Epoch 99/100
# 1174/1174 - 6s - loss: 0.2992 - accuracy: 0.8898 - 6s/epoch - 5ms/step
# Epoch 100/100
# 1174/1174 - 5s - loss: 0.3350 - accuracy: 0.8799 - 5s/epoch - 4ms/step

# %%
# Evaluate the model using the training data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 294/294 - 1s - loss: 0.3473 - accuracy: 0.8795 - 831ms/epoch - 3ms/step
# Loss: 0.3472852408885956, Accuracy: 0.879514217376709

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
print(y_true)
print(y_pred)
# Out:
# 294/294 [==============================] - 1s 2ms/step
# [5 1 4 ... 2 6 0]
# [5 1 4 ... 0 6 0]

# %%
pred=model.predict(X_test)
pred
# Out:
# 294/294 [==============================] - 1s 3ms/step
# array([[4.66845618e-10, 2.52161735e-05, 1.77231419e-03, ...,
#         5.03356932e-05, 9.98144984e-01, 7.13741747e-06],
#        [3.72589479e-04, 9.88827169e-01, 1.12193299e-03, ...,
#         1.31994957e-05, 8.19875723e-09, 5.64251764e-07],
#        [4.46647317e-14, 1.04817049e-11, 4.76469402e-04, ...,
#         9.99511302e-01, 1.28728645e-22, 1.21608718e-05],
#        ...,
#        [6.31309450e-01, 9.14372413e-06, 8.48620906e-02, ...,
#         4.20503840e-02, 1.13386252e-10, 2.41768956e-01],
#        [4.45514132e-08, 1.03915127e-05, 1.02425724e-01, ...,
#         1.79821048e-02, 1.44939533e-36, 8.79581749e-01],
#        [9.37102377e-01, 5.92554919e-02, 2.01503932e-03, ...,
#         1.01722218e-03, 1.18979401e-11, 5.39022440e-04]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.91      1.00      0.95      1359
#          bcc       0.88      0.97      0.92      1318
#          bkl       0.84      0.67      0.74      1262
#           df       0.98      1.00      0.99      1351
#           nv       0.78      0.71      0.75      1374
#         vasc       1.00      0.99      1.00      1358
#          mel       0.76      0.81      0.78      1365
#
#     accuracy                           0.88      9387
#    macro avg       0.88      0.88      0.88      9387
# weighted avg       0.88      0.88      0.88      9387

# %%
# Grab just one data point to test with
test = np.expand_dims(X_train[0], axis=0)
test.shape
# Out:
# (1, 2352)

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationWithScalingMoreOptimisations.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationWithScalingMoreOptimisations.h5")
