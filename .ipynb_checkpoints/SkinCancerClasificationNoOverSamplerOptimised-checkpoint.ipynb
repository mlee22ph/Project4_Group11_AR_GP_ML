# %% [markdown]
# # **SkinCancerClasification - No OverSampler and Optimised**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction (Without Scaling and One Hot Encoding)**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (8012, 2352)
# Testing Shape: (2003, 2352)

# %% [markdown]
# ### **Create Sequential Model with 64 units**

# %%
# Increased units to 100
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 246107 (961.36 KB)
# Trainable params: 246107 (961.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased Epoch to 50
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=50,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/50
# 251/251 - 4s - loss: 1.0243 - accuracy: 0.6640 - 4s/epoch - 16ms/step
# Epoch 2/50
# 251/251 - 3s - loss: 0.8335 - accuracy: 0.7057 - 3s/epoch - 10ms/step
# Epoch 3/50
# 251/251 - 3s - loss: 0.7748 - accuracy: 0.7222 - 3s/epoch - 11ms/step
# Epoch 4/50
# 251/251 - 4s - loss: 0.7260 - accuracy: 0.7323 - 4s/epoch - 14ms/step
# Epoch 5/50
# 251/251 - 2s - loss: 0.6785 - accuracy: 0.7539 - 2s/epoch - 9ms/step
# Epoch 6/50
# 251/251 - 1s - loss: 0.6450 - accuracy: 0.7641 - 1s/epoch - 5ms/step
# Epoch 7/50
# 251/251 - 1s - loss: 0.5986 - accuracy: 0.7792 - 1s/epoch - 5ms/step
# Epoch 8/50
# 251/251 - 1s - loss: 0.5616 - accuracy: 0.7898 - 1s/epoch - 5ms/step
# Epoch 9/50
# 251/251 - 1s - loss: 0.5461 - accuracy: 0.8009 - 1s/epoch - 5ms/step
# Epoch 10/50
# 251/251 - 1s - loss: 0.5261 - accuracy: 0.8079 - 1s/epoch - 6ms/step
# Epoch 11/50
# 251/251 - 1s - loss: 0.4901 - accuracy: 0.8201 - 1s/epoch - 6ms/step
# Epoch 12/50
# 251/251 - 2s - loss: 0.4535 - accuracy: 0.8305 - 2s/epoch - 8ms/step
# Epoch 13/50
# 251/251 - 2s - loss: 0.4309 - accuracy: 0.8417 - 2s/epoch - 9ms/step
# Epoch 14/50
# 251/251 - 1s - loss: 0.4252 - accuracy: 0.8429 - 1s/epoch - 6ms/step
# Epoch 15/50
# 251/251 - 1s - loss: 0.3950 - accuracy: 0.8588 - 1s/epoch - 6ms/step
# Epoch 16/50
# 251/251 - 1s - loss: 0.3765 - accuracy: 0.8613 - 1s/epoch - 5ms/step
# Epoch 17/50
# 251/251 - 1s - loss: 0.3558 - accuracy: 0.8691 - 1s/epoch - 6ms/step
# Epoch 18/50
# 251/251 - 1s - loss: 0.3395 - accuracy: 0.8812 - 1s/epoch - 5ms/step
# Epoch 19/50
# 251/251 - 1s - loss: 0.3437 - accuracy: 0.8752 - 1s/epoch - 6ms/step
# Epoch 20/50
# 251/251 - 1s - loss: 0.2882 - accuracy: 0.8969 - 1s/epoch - 6ms/step
# Epoch 21/50
# 251/251 - 2s - loss: 0.3075 - accuracy: 0.8878 - 2s/epoch - 9ms/step
# Epoch 22/50
# 251/251 - 2s - loss: 0.2760 - accuracy: 0.9025 - 2s/epoch - 8ms/step
# Epoch 23/50
# 251/251 - 1s - loss: 0.2838 - accuracy: 0.8962 - 1s/epoch - 5ms/step
# Epoch 24/50
# 251/251 - 1s - loss: 0.2484 - accuracy: 0.9065 - 1s/epoch - 5ms/step
# Epoch 25/50
# 251/251 - 1s - loss: 0.2515 - accuracy: 0.9104 - 1s/epoch - 5ms/step
# Epoch 26/50
# 251/251 - 1s - loss: 0.2244 - accuracy: 0.9216 - 1s/epoch - 5ms/step
# Epoch 27/50
# 251/251 - 1s - loss: 0.2134 - accuracy: 0.9206 - 1s/epoch - 5ms/step
# Epoch 28/50
# 251/251 - 1s - loss: 0.2101 - accuracy: 0.9229 - 1s/epoch - 5ms/step
# Epoch 29/50
# 251/251 - 1s - loss: 0.2144 - accuracy: 0.9236 - 1s/epoch - 5ms/step
# Epoch 30/50
# 251/251 - 2s - loss: 0.1696 - accuracy: 0.9370 - 2s/epoch - 9ms/step
# Epoch 31/50
# 251/251 - 2s - loss: 0.1683 - accuracy: 0.9397 - 2s/epoch - 8ms/step
# Epoch 32/50
# 251/251 - 1s - loss: 0.1904 - accuracy: 0.9314 - 1s/epoch - 6ms/step
# Epoch 33/50
# 251/251 - 1s - loss: 0.1888 - accuracy: 0.9327 - 1s/epoch - 6ms/step
# Epoch 34/50
# 251/251 - 1s - loss: 0.1623 - accuracy: 0.9421 - 1s/epoch - 5ms/step
# Epoch 35/50
# 251/251 - 1s - loss: 0.1671 - accuracy: 0.9398 - 1s/epoch - 5ms/step
# Epoch 36/50
# 251/251 - 1s - loss: 0.1489 - accuracy: 0.9465 - 1s/epoch - 5ms/step
# Epoch 37/50
# 251/251 - 1s - loss: 0.1528 - accuracy: 0.9452 - 1s/epoch - 6ms/step
# Epoch 38/50
# 251/251 - 1s - loss: 0.1650 - accuracy: 0.9416 - 1s/epoch - 5ms/step
# Epoch 39/50
# 251/251 - 2s - loss: 0.1247 - accuracy: 0.9548 - 2s/epoch - 8ms/step
# Epoch 40/50
# 251/251 - 2s - loss: 0.1896 - accuracy: 0.9319 - 2s/epoch - 8ms/step
# Epoch 41/50
# 251/251 - 1s - loss: 0.1419 - accuracy: 0.9513 - 1s/epoch - 5ms/step
# Epoch 42/50
# 251/251 - 1s - loss: 0.0946 - accuracy: 0.9667 - 1s/epoch - 5ms/step
# Epoch 43/50
# 251/251 - 1s - loss: 0.1003 - accuracy: 0.9666 - 1s/epoch - 5ms/step
# Epoch 44/50
# 251/251 - 1s - loss: 0.1165 - accuracy: 0.9607 - 1s/epoch - 5ms/step
# Epoch 45/50
# 251/251 - 1s - loss: 0.1267 - accuracy: 0.9559 - 1s/epoch - 5ms/step
# Epoch 46/50
# 251/251 - 1s - loss: 0.1660 - accuracy: 0.9445 - 1s/epoch - 5ms/step
# Epoch 47/50
# 251/251 - 1s - loss: 0.1217 - accuracy: 0.9596 - 1s/epoch - 5ms/step
# Epoch 48/50
# 251/251 - 2s - loss: 0.1070 - accuracy: 0.9638 - 2s/epoch - 7ms/step
# Epoch 49/50
# 251/251 - 2s - loss: 0.0806 - accuracy: 0.9720 - 2s/epoch - 9ms/step
# Epoch 50/50
# 251/251 - 1s - loss: 0.1382 - accuracy: 0.9573 - 1s/epoch - 6ms/step

# %%
# Evaluate the model using the training data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 63/63 - 0s - loss: 1.9917 - accuracy: 0.7269 - 318ms/epoch - 5ms/step
# Loss: 1.9916578531265259, Accuracy: 0.7269096374511719

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
print(y_true)
print(y_pred)
# Out:
# 63/63 [==============================] - 0s 3ms/step
# [4 4 4 ... 4 2 4]
# [4 4 4 ... 4 4 4]

# %%
pred=model.predict(X_test)
pred
# Out:
# 63/63 [==============================] - 0s 3ms/step
# array([[1.44553989e-18, 1.28556529e-21, 1.27014441e-10, ...,
#         9.99999940e-01, 1.03828708e-12, 4.38154069e-10],
#        [8.59997250e-17, 2.28318710e-16, 1.23661220e-15, ...,
#         9.99999940e-01, 4.21551796e-18, 1.79167560e-14],
#        [4.71048660e-26, 4.64472685e-14, 9.63269429e-08, ...,
#         9.99999821e-01, 1.14148071e-18, 1.07611809e-15],
#        ...,
#        [2.81152390e-09, 5.46158917e-05, 5.33420884e-04, ...,
#         9.99393463e-01, 1.58444527e-06, 1.69573032e-05],
#        [6.37247751e-07, 1.49047255e-05, 2.72775833e-02, ...,
#         9.66669023e-01, 9.39905135e-07, 6.03683153e-03],
#        [1.03315065e-14, 2.64521077e-05, 1.41737144e-06, ...,
#         9.99310493e-01, 4.07877451e-06, 6.57541794e-04]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.36      0.43      0.39        61
#          bcc       0.46      0.44      0.45        96
#          bkl       0.50      0.38      0.43       228
#           df       0.31      0.14      0.19        37
#           nv       0.84      0.91      0.87      1327
#         vasc       0.53      0.50      0.52        32
#          mel       0.43      0.36      0.39       222
#
#     accuracy                           0.73      2003
#    macro avg       0.49      0.45      0.46      2003
# weighted avg       0.71      0.73      0.71      2003

# %%
# Grab just one data point to test with
# test = np.expand_dims(X_train[0], axis=0)
# test.shape

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationNoOverSamplerOptimised.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationNoOverSamplerOptimised.h5")
