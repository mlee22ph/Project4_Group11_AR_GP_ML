# %% [markdown]
# # **SkinCancerClasification - With Scaling, First Optimisation**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
# Sklearn scaling
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Use RandomOverSampler**

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
#x = np.array(x).reshape(-1,28,28,3)
print('After RandomOverSampler - Shape of X :',x.shape)
print('After RandomOverSampler - Shape of Y :',y.shape)
# Out:
# After RandomOverSampler - Shape of X : (46935, 2352)
# After RandomOverSampler - Shape of Y : (46935,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
# This process is often referred to as z-score normalization or standardization.
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (37548, 2352)
# Testing Shape: (9387, 2352)

# %% [markdown]
# ### **Scaling and Normalization**

# %%
# Next, we normalize our training data to be between 0 and 1
scaler = MinMaxScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### **Create Sequential Model**

# %% [markdown]
# **With 64 units:**
#
# 294/294 - 0s - loss: 0.8530 - accuracy: 0.6736 - 413ms/epoch - 1ms/step
# Loss: 0.8530402183532715, Accuracy: 0.673591136932373

# %%
# Increased units from 64 to 100
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 246107 (961.36 KB)
# Trainable params: 246107 (961.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased epochs from 20 to 50
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=50,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/50
# 1174/1174 - 7s - loss: 1.6379 - accuracy: 0.3429 - 7s/epoch - 6ms/step
# Epoch 2/50
# 1174/1174 - 4s - loss: 1.3740 - accuracy: 0.4617 - 4s/epoch - 4ms/step
# Epoch 3/50
# 1174/1174 - 5s - loss: 1.2661 - accuracy: 0.5086 - 5s/epoch - 4ms/step
# Epoch 4/50
# 1174/1174 - 5s - loss: 1.2013 - accuracy: 0.5353 - 5s/epoch - 4ms/step
# Epoch 5/50
# 1174/1174 - 4s - loss: 1.1351 - accuracy: 0.5624 - 4s/epoch - 4ms/step
# Epoch 6/50
# 1174/1174 - 6s - loss: 1.0876 - accuracy: 0.5836 - 6s/epoch - 5ms/step
# Epoch 7/50
# 1174/1174 - 4s - loss: 1.0479 - accuracy: 0.5997 - 4s/epoch - 4ms/step
# Epoch 8/50
# 1174/1174 - 5s - loss: 1.0075 - accuracy: 0.6156 - 5s/epoch - 4ms/step
# Epoch 9/50
# 1174/1174 - 6s - loss: 0.9805 - accuracy: 0.6259 - 6s/epoch - 5ms/step
# Epoch 10/50
# 1174/1174 - 4s - loss: 0.9454 - accuracy: 0.6390 - 4s/epoch - 4ms/step
# Epoch 11/50
# 1174/1174 - 5s - loss: 0.9110 - accuracy: 0.6523 - 5s/epoch - 4ms/step
# Epoch 12/50
# 1174/1174 - 6s - loss: 0.8927 - accuracy: 0.6619 - 6s/epoch - 5ms/step
# Epoch 13/50
# 1174/1174 - 4s - loss: 0.8721 - accuracy: 0.6702 - 4s/epoch - 4ms/step
# Epoch 14/50
# 1174/1174 - 5s - loss: 0.8479 - accuracy: 0.6820 - 5s/epoch - 4ms/step
# Epoch 15/50
# 1174/1174 - 5s - loss: 0.8361 - accuracy: 0.6830 - 5s/epoch - 4ms/step
# Epoch 16/50
# 1174/1174 - 4s - loss: 0.8016 - accuracy: 0.6977 - 4s/epoch - 4ms/step
# Epoch 17/50
# 1174/1174 - 5s - loss: 0.8072 - accuracy: 0.6989 - 5s/epoch - 5ms/step
# Epoch 18/50
# 1174/1174 - 5s - loss: 0.7798 - accuracy: 0.7085 - 5s/epoch - 4ms/step
# Epoch 19/50
# 1174/1174 - 5s - loss: 0.7735 - accuracy: 0.7102 - 5s/epoch - 4ms/step
# Epoch 20/50
# 1174/1174 - 6s - loss: 0.7472 - accuracy: 0.7191 - 6s/epoch - 5ms/step
# Epoch 21/50
# 1174/1174 - 4s - loss: 0.7428 - accuracy: 0.7200 - 4s/epoch - 4ms/step
# Epoch 22/50
# 1174/1174 - 5s - loss: 0.7327 - accuracy: 0.7260 - 5s/epoch - 4ms/step
# Epoch 23/50
# 1174/1174 - 5s - loss: 0.7178 - accuracy: 0.7326 - 5s/epoch - 5ms/step
# Epoch 24/50
# 1174/1174 - 4s - loss: 0.7133 - accuracy: 0.7325 - 4s/epoch - 4ms/step
# Epoch 25/50
# 1174/1174 - 5s - loss: 0.6976 - accuracy: 0.7398 - 5s/epoch - 5ms/step
# Epoch 26/50
# 1174/1174 - 5s - loss: 0.6897 - accuracy: 0.7412 - 5s/epoch - 4ms/step
# Epoch 27/50
# 1174/1174 - 4s - loss: 0.6828 - accuracy: 0.7451 - 4s/epoch - 4ms/step
# Epoch 28/50
# 1174/1174 - 6s - loss: 0.6709 - accuracy: 0.7498 - 6s/epoch - 5ms/step
# Epoch 29/50
# 1174/1174 - 4s - loss: 0.6848 - accuracy: 0.7436 - 4s/epoch - 4ms/step
# Epoch 30/50
# 1174/1174 - 4s - loss: 0.6535 - accuracy: 0.7528 - 4s/epoch - 4ms/step
# Epoch 31/50
# 1174/1174 - 6s - loss: 0.6349 - accuracy: 0.7626 - 6s/epoch - 5ms/step
# Epoch 32/50
# 1174/1174 - 4s - loss: 0.6620 - accuracy: 0.7527 - 4s/epoch - 4ms/step
# Epoch 33/50
# 1174/1174 - 4s - loss: 0.6236 - accuracy: 0.7674 - 4s/epoch - 4ms/step
# Epoch 34/50
# 1174/1174 - 6s - loss: 0.6187 - accuracy: 0.7673 - 6s/epoch - 5ms/step
# Epoch 35/50
# 1174/1174 - 4s - loss: 0.6236 - accuracy: 0.7653 - 4s/epoch - 4ms/step
# Epoch 36/50
# 1174/1174 - 5s - loss: 0.6309 - accuracy: 0.7618 - 5s/epoch - 4ms/step
# Epoch 37/50
# 1174/1174 - 5s - loss: 0.6031 - accuracy: 0.7730 - 5s/epoch - 4ms/step
# Epoch 38/50
# 1174/1174 - 4s - loss: 0.6088 - accuracy: 0.7716 - 4s/epoch - 4ms/step
# Epoch 39/50
# 1174/1174 - 5s - loss: 0.5975 - accuracy: 0.7750 - 5s/epoch - 5ms/step
# Epoch 40/50
# 1174/1174 - 5s - loss: 0.5865 - accuracy: 0.7801 - 5s/epoch - 4ms/step
# Epoch 41/50
# 1174/1174 - 4s - loss: 0.5866 - accuracy: 0.7809 - 4s/epoch - 4ms/step
# Epoch 42/50
# 1174/1174 - 6s - loss: 0.5934 - accuracy: 0.7780 - 6s/epoch - 5ms/step
# Epoch 43/50
# 1174/1174 - 4s - loss: 0.5790 - accuracy: 0.7831 - 4s/epoch - 4ms/step
# Epoch 44/50
# 1174/1174 - 4s - loss: 0.5674 - accuracy: 0.7866 - 4s/epoch - 4ms/step
# Epoch 45/50
# 1174/1174 - 6s - loss: 0.5659 - accuracy: 0.7850 - 6s/epoch - 5ms/step
# Epoch 46/50
# 1174/1174 - 4s - loss: 0.5519 - accuracy: 0.7938 - 4s/epoch - 4ms/step
# Epoch 47/50
# 1174/1174 - 4s - loss: 0.5765 - accuracy: 0.7831 - 4s/epoch - 4ms/step
# Epoch 48/50
# 1174/1174 - 5s - loss: 0.5690 - accuracy: 0.7832 - 5s/epoch - 5ms/step
# Epoch 49/50
# 1174/1174 - 4s - loss: 0.5519 - accuracy: 0.7913 - 4s/epoch - 4ms/step
# Epoch 50/50
# 1174/1174 - 5s - loss: 0.5541 - accuracy: 0.7917 - 5s/epoch - 4ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 294/294 - 1s - loss: 0.5175 - accuracy: 0.8084 - 666ms/epoch - 2ms/step
# Loss: 0.5175021886825562, Accuracy: 0.808351993560791

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("SkinCancerClasificationWithScaling1stOptimisation-ModelAccuracy.png")
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
# Print result and prediction for side by side comparison
print(y_true)
print(y_pred)
# Out:
# 294/294 [==============================] - 1s 2ms/step
# [5 1 4 ... 2 6 0]
# [5 1 4 ... 0 1 0]

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.83      0.91      0.87      1359
#          bcc       0.87      0.78      0.82      1318
#          bkl       0.59      0.68      0.63      1262
#           df       0.93      1.00      0.96      1351
#           nv       0.86      0.56      0.68      1374
#         vasc       0.97      1.00      0.98      1358
#          mel       0.66      0.72      0.69      1365
#
#     accuracy                           0.81      9387
#    macro avg       0.81      0.81      0.80      9387
# weighted avg       0.82      0.81      0.81      9387

# %%
# Print confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_df = pd.DataFrame(
    cm, index=["Actual akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"], columns=["Predicted akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
)
display(cm_df)
# Out:
#               Predicted akiec   bcc  bkl    df   nv  vasc  mel
# Actual akiec             1243    26   49    19    0     0   22
# bcc                       137  1024   78    21   16    17   25
# bkl                        55    54  859    20   73     6  195
# df                          0     0    0  1351    0     0    0
# nv                         42    44  200    31  773    15  269
# vasc                        0     0    0     0    0  1358    0
# mel                        28    30  269    16   36     6  980

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationWithScaling1stOptimisation.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationWithScaling1stOptimisation.h5")
