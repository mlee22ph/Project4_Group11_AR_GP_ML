# %% [markdown]
# # **SkinCancerClasification - No OverSampler, No Scaling, Optimised**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction (Without Scaling and One Hot Encoding)**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
# This process is often referred to as z-score normalization or standardization.
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (8012, 2352)
# Testing Shape: (2003, 2352)

# %% [markdown]
# ### **Create Sequential Model with 100 units**

# %% [markdown]
# **With 64 units:**
#
#
# 63/63 - 0s - loss: 1.0296 - accuracy: 0.7174 - 326ms/epoch - 5ms/step
# Loss: 1.0296320915222168, Accuracy: 0.7174238562583923

# %%
# Increased units from 64 to 100
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 246107 (961.36 KB)
# Trainable params: 246107 (961.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased Epoch from 20 to 50
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=50,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/50
# 251/251 - 3s - loss: 1.0046 - accuracy: 0.6676 - 3s/epoch - 13ms/step
# Epoch 2/50
# 251/251 - 2s - loss: 0.8399 - accuracy: 0.7017 - 2s/epoch - 7ms/step
# Epoch 3/50
# 251/251 - 1s - loss: 0.7698 - accuracy: 0.7208 - 1s/epoch - 5ms/step
# Epoch 4/50
# 251/251 - 1s - loss: 0.7113 - accuracy: 0.7401 - 1s/epoch - 5ms/step
# Epoch 5/50
# 251/251 - 1s - loss: 0.6679 - accuracy: 0.7544 - 1s/epoch - 5ms/step
# Epoch 6/50
# 251/251 - 2s - loss: 0.6520 - accuracy: 0.7615 - 2s/epoch - 9ms/step
# Epoch 7/50
# 251/251 - 2s - loss: 0.6070 - accuracy: 0.7717 - 2s/epoch - 9ms/step
# Epoch 8/50
# 251/251 - 3s - loss: 0.5726 - accuracy: 0.7859 - 3s/epoch - 10ms/step
# Epoch 9/50
# 251/251 - 3s - loss: 0.5472 - accuracy: 0.7972 - 3s/epoch - 12ms/step
# Epoch 10/50
# 251/251 - 2s - loss: 0.5140 - accuracy: 0.8074 - 2s/epoch - 8ms/step
# Epoch 11/50
# 251/251 - 2s - loss: 0.4965 - accuracy: 0.8238 - 2s/epoch - 8ms/step
# Epoch 12/50
# 251/251 - 2s - loss: 0.4696 - accuracy: 0.8281 - 2s/epoch - 8ms/step
# Epoch 13/50
# 251/251 - 2s - loss: 0.4282 - accuracy: 0.8470 - 2s/epoch - 9ms/step
# Epoch 14/50
# 251/251 - 2s - loss: 0.4386 - accuracy: 0.8376 - 2s/epoch - 9ms/step
# Epoch 15/50
# 251/251 - 3s - loss: 0.3911 - accuracy: 0.8581 - 3s/epoch - 11ms/step
# Epoch 16/50
# 251/251 - 2s - loss: 0.3915 - accuracy: 0.8571 - 2s/epoch - 10ms/step
# Epoch 17/50
# 251/251 - 2s - loss: 0.3561 - accuracy: 0.8697 - 2s/epoch - 8ms/step
# Epoch 18/50
# 251/251 - 2s - loss: 0.3373 - accuracy: 0.8761 - 2s/epoch - 9ms/step
# Epoch 19/50
# 251/251 - 2s - loss: 0.3178 - accuracy: 0.8850 - 2s/epoch - 8ms/step
# Epoch 20/50
# 251/251 - 2s - loss: 0.3086 - accuracy: 0.8878 - 2s/epoch - 8ms/step
# Epoch 21/50
# 251/251 - 2s - loss: 0.2950 - accuracy: 0.8922 - 2s/epoch - 9ms/step
# Epoch 22/50
# 251/251 - 2s - loss: 0.2673 - accuracy: 0.9035 - 2s/epoch - 7ms/step
# Epoch 23/50
# 251/251 - 1s - loss: 0.2759 - accuracy: 0.9018 - 1s/epoch - 5ms/step
# Epoch 24/50
# 251/251 - 1s - loss: 0.2263 - accuracy: 0.9195 - 1s/epoch - 5ms/step
# Epoch 25/50
# 251/251 - 1s - loss: 0.2239 - accuracy: 0.9185 - 1s/epoch - 5ms/step
# Epoch 26/50
# 251/251 - 1s - loss: 0.2350 - accuracy: 0.9118 - 1s/epoch - 5ms/step
# Epoch 27/50
# 251/251 - 1s - loss: 0.2217 - accuracy: 0.9231 - 1s/epoch - 5ms/step
# Epoch 28/50
# 251/251 - 1s - loss: 0.2158 - accuracy: 0.9202 - 1s/epoch - 5ms/step
# Epoch 29/50
# 251/251 - 1s - loss: 0.1821 - accuracy: 0.9336 - 1s/epoch - 5ms/step
# Epoch 30/50
# 251/251 - 1s - loss: 0.1623 - accuracy: 0.9417 - 1s/epoch - 6ms/step
# Epoch 31/50
# 251/251 - 2s - loss: 0.1805 - accuracy: 0.9340 - 2s/epoch - 8ms/step
# Epoch 32/50
# 251/251 - 2s - loss: 0.1330 - accuracy: 0.9546 - 2s/epoch - 6ms/step
# Epoch 33/50
# 251/251 - 1s - loss: 0.1696 - accuracy: 0.9375 - 1s/epoch - 5ms/step
# Epoch 34/50
# 251/251 - 1s - loss: 0.1975 - accuracy: 0.9310 - 1s/epoch - 5ms/step
# Epoch 35/50
# 251/251 - 1s - loss: 0.1701 - accuracy: 0.9400 - 1s/epoch - 5ms/step
# Epoch 36/50
# 251/251 - 1s - loss: 0.1232 - accuracy: 0.9576 - 1s/epoch - 5ms/step
# Epoch 37/50
# 251/251 - 1s - loss: 0.1365 - accuracy: 0.9533 - 1s/epoch - 5ms/step
# Epoch 38/50
# 251/251 - 1s - loss: 0.1175 - accuracy: 0.9602 - 1s/epoch - 5ms/step
# Epoch 39/50
# 251/251 - 1s - loss: 0.1464 - accuracy: 0.9506 - 1s/epoch - 5ms/step
# Epoch 40/50
# 251/251 - 1s - loss: 0.1528 - accuracy: 0.9471 - 1s/epoch - 5ms/step
# Epoch 41/50
# 251/251 - 2s - loss: 0.1510 - accuracy: 0.9485 - 2s/epoch - 8ms/step
# Epoch 42/50
# 251/251 - 2s - loss: 0.0997 - accuracy: 0.9649 - 2s/epoch - 6ms/step
# Epoch 43/50
# 251/251 - 1s - loss: 0.1072 - accuracy: 0.9623 - 1s/epoch - 5ms/step
# Epoch 44/50
# 251/251 - 1s - loss: 0.1097 - accuracy: 0.9622 - 1s/epoch - 5ms/step
# Epoch 45/50
# 251/251 - 1s - loss: 0.1488 - accuracy: 0.9483 - 1s/epoch - 5ms/step
# Epoch 46/50
# 251/251 - 1s - loss: 0.1318 - accuracy: 0.9562 - 1s/epoch - 5ms/step
# Epoch 47/50
# 251/251 - 1s - loss: 0.0897 - accuracy: 0.9690 - 1s/epoch - 5ms/step
# Epoch 48/50
# 251/251 - 1s - loss: 0.0878 - accuracy: 0.9687 - 1s/epoch - 5ms/step
# Epoch 49/50
# 251/251 - 1s - loss: 0.1195 - accuracy: 0.9609 - 1s/epoch - 5ms/step
# Epoch 50/50
# 251/251 - 2s - loss: 0.1173 - accuracy: 0.9626 - 2s/epoch - 6ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 63/63 - 0s - loss: 2.0497 - accuracy: 0.7364 - 290ms/epoch - 5ms/step
# Loss: 2.0497190952301025, Accuracy: 0.7363954186439514

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("SkinCancerClasificationNoOverSamplerOptimised-ModelAccuracy.png")
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
# Print result and prediction for side by side comparison
print(y_true)
print(y_pred)
# Out:
# 63/63 [==============================] - 0s 4ms/step
# [4 4 4 ... 4 2 4]
# [4 4 4 ... 4 2 4]

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.46      0.51      0.48        61
#          bcc       0.52      0.52      0.52        96
#          bkl       0.48      0.45      0.46       228
#           df       0.60      0.16      0.26        37
#           nv       0.84      0.90      0.87      1327
#         vasc       0.67      0.38      0.48        32
#          mel       0.44      0.34      0.39       222
#
#     accuracy                           0.74      2003
#    macro avg       0.57      0.47      0.49      2003
# weighted avg       0.72      0.74      0.72      2003

# %%
# Print confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_df = pd.DataFrame(
    cm, index=["Actual akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"], columns=["Predicted akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
)
display(cm_df)
# Out:
#               Predicted akiec  bcc  bkl  df    nv  vasc  mel
# Actual akiec               31    6    4   1    17     0    2
# bcc                         7   50   15   0    17     3    4
# bkl                         8   11  102   1    76     0   30
# df                          6    9    7   6     7     1    1
# nv                          8   12   49   0  1198     2   58
# vasc                        0    6    3   0    10    12    1
# mel                         7    3   31   2   103     0   76

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationNoOverSamplerOptimised.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationNoOverSamplerOptimised.h5")
