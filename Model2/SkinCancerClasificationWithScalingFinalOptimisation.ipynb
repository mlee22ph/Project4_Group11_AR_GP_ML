# %% [markdown]
# # **SkinCancerClasification - With Scaling and more Optimisations**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
# Sklearn scaling
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Use RandomOverSampler**

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
#x = np.array(x).reshape(-1,28,28,3)
print('After RandomOverSampler - Shape of X :',x.shape)
print('After RandomOverSampler - Shape of Y :',y.shape)
# Out:
# After RandomOverSampler - Shape of X : (46935, 2352)
# After RandomOverSampler - Shape of Y : (46935,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
# This process is often referred to as z-score normalization or standardization.
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (37548, 2352)
# Testing Shape: (9387, 2352)

# %% [markdown]
# ### **Scaling and Normalization**

# %%
# Next, we normalize our training data to be between 0 and 1
scaler = MinMaxScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### **Create Sequential Model**

# %% [markdown]
# **With 100 units and 50 epochs:**
#
# 294/294 - 1s - loss: 0.5935 - accuracy: 0.7836 - 912ms/epoch - 3ms/step
# Loss: 0.5934981107711792, Accuracy: 0.7836369276046753
#
# **With 100 units and 100 epochs:**
# 294/294 - 0s - loss: 0.3575 - accuracy: 0.8681 - 431ms/epoch - 1ms/step
# Loss: 0.35752636194229126, Accuracy: 0.8681154847145081

# %%
# Added another layer to make 4 layers in total
# Increased units 100
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add a third hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 256207 (1000.81 KB)
# Trainable params: 256207 (1000.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased epochs to 100
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 1174/1174 - 8s - loss: 1.6170 - accuracy: 0.3512 - 8s/epoch - 6ms/step
# Epoch 2/100
# 1174/1174 - 8s - loss: 1.3397 - accuracy: 0.4793 - 8s/epoch - 6ms/step
# Epoch 3/100
# 1174/1174 - 6s - loss: 1.2326 - accuracy: 0.5233 - 6s/epoch - 5ms/step
# Epoch 4/100
# 1174/1174 - 8s - loss: 1.1457 - accuracy: 0.5582 - 8s/epoch - 6ms/step
# Epoch 5/100
# 1174/1174 - 6s - loss: 1.0779 - accuracy: 0.5863 - 6s/epoch - 6ms/step
# Epoch 6/100
# 1174/1174 - 8s - loss: 1.0027 - accuracy: 0.6163 - 8s/epoch - 7ms/step
# Epoch 7/100
# 1174/1174 - 6s - loss: 0.9485 - accuracy: 0.6398 - 6s/epoch - 5ms/step
# Epoch 8/100
# 1174/1174 - 8s - loss: 0.8840 - accuracy: 0.6660 - 8s/epoch - 7ms/step
# Epoch 9/100
# 1174/1174 - 6s - loss: 0.8592 - accuracy: 0.6723 - 6s/epoch - 5ms/step
# Epoch 10/100
# 1174/1174 - 7s - loss: 0.8044 - accuracy: 0.6939 - 7s/epoch - 6ms/step
# Epoch 11/100
# 1174/1174 - 6s - loss: 0.7798 - accuracy: 0.7029 - 6s/epoch - 5ms/step
# Epoch 12/100
# 1174/1174 - 7s - loss: 0.7451 - accuracy: 0.7160 - 7s/epoch - 6ms/step
# Epoch 13/100
# 1174/1174 - 6s - loss: 0.7214 - accuracy: 0.7275 - 6s/epoch - 5ms/step
# Epoch 14/100
# 1174/1174 - 7s - loss: 0.6842 - accuracy: 0.7419 - 7s/epoch - 6ms/step
# Epoch 15/100
# 1174/1174 - 8s - loss: 0.6451 - accuracy: 0.7577 - 8s/epoch - 6ms/step
# Epoch 16/100
# 1174/1174 - 7s - loss: 0.6425 - accuracy: 0.7573 - 7s/epoch - 6ms/step
# Epoch 17/100
# 1174/1174 - 6s - loss: 0.6124 - accuracy: 0.7682 - 6s/epoch - 6ms/step
# Epoch 18/100
# 1174/1174 - 7s - loss: 0.5902 - accuracy: 0.7780 - 7s/epoch - 6ms/step
# Epoch 19/100
# 1174/1174 - 7s - loss: 0.5879 - accuracy: 0.7781 - 7s/epoch - 6ms/step
# Epoch 20/100
# 1174/1174 - 7s - loss: 0.5781 - accuracy: 0.7819 - 7s/epoch - 6ms/step
# Epoch 21/100
# 1174/1174 - 7s - loss: 0.5375 - accuracy: 0.7980 - 7s/epoch - 6ms/step
# Epoch 22/100
# 1174/1174 - 7s - loss: 0.5230 - accuracy: 0.8003 - 7s/epoch - 6ms/step
# Epoch 23/100
# 1174/1174 - 8s - loss: 0.5571 - accuracy: 0.7919 - 8s/epoch - 6ms/step
# Epoch 24/100
# 1174/1174 - 6s - loss: 0.5013 - accuracy: 0.8119 - 6s/epoch - 5ms/step
# Epoch 25/100
# 1174/1174 - 7s - loss: 0.5004 - accuracy: 0.8103 - 7s/epoch - 6ms/step
# Epoch 26/100
# 1174/1174 - 6s - loss: 0.4952 - accuracy: 0.8145 - 6s/epoch - 5ms/step
# Epoch 27/100
# 1174/1174 - 7s - loss: 0.4570 - accuracy: 0.8300 - 7s/epoch - 6ms/step
# Epoch 28/100
# 1174/1174 - 6s - loss: 0.4948 - accuracy: 0.8132 - 6s/epoch - 5ms/step
# Epoch 29/100
# 1174/1174 - 7s - loss: 0.4536 - accuracy: 0.8314 - 7s/epoch - 6ms/step
# Epoch 30/100
# 1174/1174 - 6s - loss: 0.4417 - accuracy: 0.8366 - 6s/epoch - 5ms/step
# Epoch 31/100
# 1174/1174 - 7s - loss: 0.4652 - accuracy: 0.8278 - 7s/epoch - 6ms/step
# Epoch 32/100
# 1174/1174 - 6s - loss: 0.4386 - accuracy: 0.8362 - 6s/epoch - 5ms/step
# Epoch 33/100
# 1174/1174 - 7s - loss: 0.4552 - accuracy: 0.8321 - 7s/epoch - 6ms/step
# Epoch 34/100
# 1174/1174 - 6s - loss: 0.4476 - accuracy: 0.8346 - 6s/epoch - 5ms/step
# Epoch 35/100
# 1174/1174 - 7s - loss: 0.4046 - accuracy: 0.8509 - 7s/epoch - 6ms/step
# Epoch 36/100
# 1174/1174 - 6s - loss: 0.4288 - accuracy: 0.8423 - 6s/epoch - 5ms/step
# Epoch 37/100
# 1174/1174 - 8s - loss: 0.4112 - accuracy: 0.8476 - 8s/epoch - 6ms/step
# Epoch 38/100
# 1174/1174 - 6s - loss: 0.4082 - accuracy: 0.8480 - 6s/epoch - 5ms/step
# Epoch 39/100
# 1174/1174 - 8s - loss: 0.4060 - accuracy: 0.8481 - 8s/epoch - 6ms/step
# Epoch 40/100
# 1174/1174 - 6s - loss: 0.3748 - accuracy: 0.8595 - 6s/epoch - 5ms/step
# Epoch 41/100
# 1174/1174 - 7s - loss: 0.4024 - accuracy: 0.8516 - 7s/epoch - 6ms/step
# Epoch 42/100
# 1174/1174 - 6s - loss: 0.3755 - accuracy: 0.8606 - 6s/epoch - 5ms/step
# Epoch 43/100
# 1174/1174 - 7s - loss: 0.3776 - accuracy: 0.8581 - 7s/epoch - 6ms/step
# Epoch 44/100
# 1174/1174 - 6s - loss: 0.3977 - accuracy: 0.8562 - 6s/epoch - 5ms/step
# Epoch 45/100
# 1174/1174 - 8s - loss: 0.3677 - accuracy: 0.8631 - 8s/epoch - 7ms/step
# Epoch 46/100
# 1174/1174 - 6s - loss: 0.3900 - accuracy: 0.8581 - 6s/epoch - 5ms/step
# Epoch 47/100
# 1174/1174 - 8s - loss: 0.3347 - accuracy: 0.8743 - 8s/epoch - 6ms/step
# Epoch 48/100
# 1174/1174 - 6s - loss: 0.3521 - accuracy: 0.8708 - 6s/epoch - 5ms/step
# Epoch 49/100
# 1174/1174 - 7s - loss: 0.3483 - accuracy: 0.8705 - 7s/epoch - 6ms/step
# Epoch 50/100
# 1174/1174 - 6s - loss: 0.3622 - accuracy: 0.8684 - 6s/epoch - 5ms/step
# Epoch 51/100
# 1174/1174 - 8s - loss: 0.3485 - accuracy: 0.8709 - 8s/epoch - 6ms/step
# Epoch 52/100
# 1174/1174 - 6s - loss: 0.3365 - accuracy: 0.8764 - 6s/epoch - 5ms/step
# Epoch 53/100
# 1174/1174 - 8s - loss: 0.3380 - accuracy: 0.8742 - 8s/epoch - 6ms/step
# Epoch 54/100
# 1174/1174 - 6s - loss: 0.3368 - accuracy: 0.8758 - 6s/epoch - 5ms/step
# Epoch 55/100
# 1174/1174 - 8s - loss: 0.3365 - accuracy: 0.8755 - 8s/epoch - 6ms/step
# Epoch 56/100
# 1174/1174 - 6s - loss: 0.3350 - accuracy: 0.8787 - 6s/epoch - 5ms/step
# Epoch 57/100
# 1174/1174 - 7s - loss: 0.3636 - accuracy: 0.8701 - 7s/epoch - 6ms/step
# Epoch 58/100
# 1174/1174 - 6s - loss: 0.3199 - accuracy: 0.8802 - 6s/epoch - 5ms/step
# Epoch 59/100
# 1174/1174 - 7s - loss: 0.3307 - accuracy: 0.8780 - 7s/epoch - 6ms/step
# Epoch 60/100
# 1174/1174 - 6s - loss: 0.3156 - accuracy: 0.8838 - 6s/epoch - 5ms/step
# Epoch 61/100
# 1174/1174 - 7s - loss: 0.3256 - accuracy: 0.8808 - 7s/epoch - 6ms/step
# Epoch 62/100
# 1174/1174 - 6s - loss: 0.3171 - accuracy: 0.8838 - 6s/epoch - 5ms/step
# Epoch 63/100
# 1174/1174 - 8s - loss: 0.3043 - accuracy: 0.8870 - 8s/epoch - 6ms/step
# Epoch 64/100
# 1174/1174 - 6s - loss: 0.3188 - accuracy: 0.8844 - 6s/epoch - 5ms/step
# Epoch 65/100
# 1174/1174 - 8s - loss: 0.3053 - accuracy: 0.8879 - 8s/epoch - 6ms/step
# Epoch 66/100
# 1174/1174 - 8s - loss: 0.3128 - accuracy: 0.8893 - 8s/epoch - 7ms/step
# Epoch 67/100
# 1174/1174 - 8s - loss: 0.2935 - accuracy: 0.8905 - 8s/epoch - 7ms/step
# Epoch 68/100
# 1174/1174 - 6s - loss: 0.3426 - accuracy: 0.8775 - 6s/epoch - 5ms/step
# Epoch 69/100
# 1174/1174 - 7s - loss: 0.2698 - accuracy: 0.9016 - 7s/epoch - 6ms/step
# Epoch 70/100
# 1174/1174 - 6s - loss: 0.3117 - accuracy: 0.8867 - 6s/epoch - 5ms/step
# Epoch 71/100
# 1174/1174 - 7s - loss: 0.2707 - accuracy: 0.8996 - 7s/epoch - 6ms/step
# Epoch 72/100
# 1174/1174 - 6s - loss: 0.3039 - accuracy: 0.8896 - 6s/epoch - 5ms/step
# Epoch 73/100
# 1174/1174 - 7s - loss: 0.2914 - accuracy: 0.8937 - 7s/epoch - 6ms/step
# Epoch 74/100
# 1174/1174 - 6s - loss: 0.2902 - accuracy: 0.8927 - 6s/epoch - 5ms/step
# Epoch 75/100
# 1174/1174 - 7s - loss: 0.2725 - accuracy: 0.9019 - 7s/epoch - 6ms/step
# Epoch 76/100
# 1174/1174 - 6s - loss: 0.3251 - accuracy: 0.8847 - 6s/epoch - 5ms/step
# Epoch 77/100
# 1174/1174 - 7s - loss: 0.2480 - accuracy: 0.9081 - 7s/epoch - 6ms/step
# Epoch 78/100
# 1174/1174 - 6s - loss: 0.3050 - accuracy: 0.8920 - 6s/epoch - 5ms/step
# Epoch 79/100
# 1174/1174 - 7s - loss: 0.2667 - accuracy: 0.9014 - 7s/epoch - 6ms/step
# Epoch 80/100
# 1174/1174 - 6s - loss: 0.2809 - accuracy: 0.8987 - 6s/epoch - 5ms/step
# Epoch 81/100
# 1174/1174 - 7s - loss: 0.2887 - accuracy: 0.8962 - 7s/epoch - 6ms/step
# Epoch 82/100
# 1174/1174 - 6s - loss: 0.2664 - accuracy: 0.9027 - 6s/epoch - 5ms/step
# Epoch 83/100
# 1174/1174 - 7s - loss: 0.2879 - accuracy: 0.8945 - 7s/epoch - 6ms/step
# Epoch 84/100
# 1174/1174 - 6s - loss: 0.2797 - accuracy: 0.8998 - 6s/epoch - 5ms/step
# Epoch 85/100
# 1174/1174 - 7s - loss: 0.2575 - accuracy: 0.9050 - 7s/epoch - 6ms/step
# Epoch 86/100
# 1174/1174 - 6s - loss: 0.2661 - accuracy: 0.9051 - 6s/epoch - 5ms/step
# Epoch 87/100
# 1174/1174 - 7s - loss: 0.3022 - accuracy: 0.8942 - 7s/epoch - 6ms/step
# Epoch 88/100
# 1174/1174 - 6s - loss: 0.2586 - accuracy: 0.9054 - 6s/epoch - 5ms/step
# Epoch 89/100
# 1174/1174 - 8s - loss: 0.2829 - accuracy: 0.9020 - 8s/epoch - 6ms/step
# Epoch 90/100
# 1174/1174 - 6s - loss: 0.2503 - accuracy: 0.9117 - 6s/epoch - 5ms/step
# Epoch 91/100
# 1174/1174 - 8s - loss: 0.2574 - accuracy: 0.9067 - 8s/epoch - 6ms/step
# Epoch 92/100
# 1174/1174 - 6s - loss: 0.2515 - accuracy: 0.9075 - 6s/epoch - 5ms/step
# Epoch 93/100
# 1174/1174 - 8s - loss: 0.2763 - accuracy: 0.9005 - 8s/epoch - 7ms/step
# Epoch 94/100
# 1174/1174 - 6s - loss: 0.2599 - accuracy: 0.9063 - 6s/epoch - 5ms/step
# Epoch 95/100
# 1174/1174 - 7s - loss: 0.2609 - accuracy: 0.9060 - 7s/epoch - 6ms/step
# Epoch 96/100
# 1174/1174 - 7s - loss: 0.2312 - accuracy: 0.9159 - 7s/epoch - 6ms/step
# Epoch 97/100
# 1174/1174 - 7s - loss: 0.3017 - accuracy: 0.8981 - 7s/epoch - 6ms/step
# Epoch 98/100
# 1174/1174 - 7s - loss: 0.2229 - accuracy: 0.9172 - 7s/epoch - 6ms/step
# Epoch 99/100
# 1174/1174 - 7s - loss: 0.2762 - accuracy: 0.9031 - 7s/epoch - 6ms/step
# Epoch 100/100
# 1174/1174 - 7s - loss: 0.2221 - accuracy: 0.9183 - 7s/epoch - 6ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 294/294 - 1s - loss: 0.2930 - accuracy: 0.9084 - 871ms/epoch - 3ms/step
# Loss: 0.2929627597332001, Accuracy: 0.9083839058876038

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("SkinCancerClasificationWithScalingFinalOptimisation-ModelAccuracy.png")
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
# Print result and prediction for side by side comparison
print(y_true)
print(y_pred)
# Out:
# 294/294 [==============================] - 1s 2ms/step
# [5 1 4 ... 2 6 0]
# [5 1 4 ... 2 6 0]

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.96      1.00      0.98      1359
#          bcc       0.95      0.96      0.95      1318
#          bkl       0.83      0.84      0.83      1262
#           df       0.99      1.00      0.99      1351
#           nv       0.83      0.67      0.74      1374
#         vasc       1.00      1.00      1.00      1358
#          mel       0.80      0.89      0.84      1365
#
#     accuracy                           0.91      9387
#    macro avg       0.91      0.91      0.91      9387
# weighted avg       0.91      0.91      0.91      9387

# %%
# Print confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_df = pd.DataFrame(
    cm, index=["Actual akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"], columns=["Predicted akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
)
display(cm_df)
# Out:
#               Predicted akiec   bcc   bkl    df   nv  vasc   mel
# Actual akiec             1353     6     0     0    0     0     0
# bcc                        25  1265    11     4   10     0     3
# bkl                        17    20  1061     1   92     0    71
# df                          0     0     0  1351    0     0     0
# nv                         17    37   153    10  927     5   225
# vasc                        0     0     0     0    0  1358     0
# mel                         2     6    56     0   89     0  1212

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationWithScalingFinalOptimisation.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationWithScalingFinalOptimisation.h5")
