# %% [markdown]
# # **SkinCancerClasification - With Scaling and more Optimisations**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
# Sklearn scaling
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Use RandomOverSampler**

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
x = np.array(x).reshape(-1,28,28,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 28, 28, 3)

# %%
print('Shape of Y :',y.shape)
# Out:
# Shape of Y : (46935,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
X_train.shape
# Out:
# (37548, 28, 28, 3)

# %%
# We want to flatten our image of 28x28 pixels to a 1D array of 784 pixels
ndims = X_train.shape[1] * X_train.shape[2] * X_train.shape[3]
X_train = X_train.reshape(X_train.shape[0], ndims)
X_test = X_test.reshape(X_test.shape[0], ndims)
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (37548, 2352)
# Testing Shape: (9387, 2352)

# %% [markdown]
# ### **Scaling and Normalization**

# %%
# Next, we normalize our training data to be between 0 and 1
scaler = MinMaxScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### **Create Sequential Model**

# %% [markdown]
# **With 64 units and 50 epochs:**
#
# 294/294 - 1s - loss: 0.9814 - accuracy: 0.6068 - 926ms/epoch - 3ms/step
# Loss: 0.9813539981842041, Accuracy: 0.6067966222763062
#
# **With 100 units and 100 epochs:**
# 294/294 - 1s - loss: 0.3473 - accuracy: 0.8795 - 831ms/epoch - 3ms/step
# Loss: 0.3472852408885956, Accuracy: 0.879514217376709

# %%
# Added another layer to make 4 layers in total
# Increased units 100
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add a third hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 256207 (1000.81 KB)
# Trainable params: 256207 (1000.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased epochs to 100
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 1174/1174 - 7s - loss: 1.6289 - accuracy: 0.3415 - 7s/epoch - 6ms/step
# Epoch 2/100
# 1174/1174 - 7s - loss: 1.3655 - accuracy: 0.4629 - 7s/epoch - 6ms/step
# Epoch 3/100
# 1174/1174 - 5s - loss: 1.2294 - accuracy: 0.5219 - 5s/epoch - 5ms/step
# Epoch 4/100
# 1174/1174 - 7s - loss: 1.1520 - accuracy: 0.5546 - 7s/epoch - 6ms/step
# Epoch 5/100
# 1174/1174 - 6s - loss: 1.0809 - accuracy: 0.5826 - 6s/epoch - 5ms/step
# Epoch 6/100
# 1174/1174 - 7s - loss: 1.0071 - accuracy: 0.6117 - 7s/epoch - 6ms/step
# Epoch 7/100
# 1174/1174 - 6s - loss: 0.9513 - accuracy: 0.6317 - 6s/epoch - 5ms/step
# Epoch 8/100
# 1174/1174 - 7s - loss: 0.8920 - accuracy: 0.6567 - 7s/epoch - 6ms/step
# Epoch 9/100
# 1174/1174 - 6s - loss: 0.8635 - accuracy: 0.6662 - 6s/epoch - 5ms/step
# Epoch 10/100
# 1174/1174 - 7s - loss: 0.8200 - accuracy: 0.6820 - 7s/epoch - 6ms/step
# Epoch 11/100
# 1174/1174 - 6s - loss: 0.7832 - accuracy: 0.6975 - 6s/epoch - 5ms/step
# Epoch 12/100
# 1174/1174 - 8s - loss: 0.7534 - accuracy: 0.7083 - 8s/epoch - 7ms/step
# Epoch 13/100
# 1174/1174 - 6s - loss: 0.7129 - accuracy: 0.7270 - 6s/epoch - 5ms/step
# Epoch 14/100
# 1174/1174 - 7s - loss: 0.6847 - accuracy: 0.7362 - 7s/epoch - 6ms/step
# Epoch 15/100
# 1174/1174 - 6s - loss: 0.6491 - accuracy: 0.7512 - 6s/epoch - 5ms/step
# Epoch 16/100
# 1174/1174 - 7s - loss: 0.6428 - accuracy: 0.7508 - 7s/epoch - 6ms/step
# Epoch 17/100
# 1174/1174 - 6s - loss: 0.6103 - accuracy: 0.7643 - 6s/epoch - 5ms/step
# Epoch 18/100
# 1174/1174 - 7s - loss: 0.5803 - accuracy: 0.7795 - 7s/epoch - 6ms/step
# Epoch 19/100
# 1174/1174 - 6s - loss: 0.5752 - accuracy: 0.7786 - 6s/epoch - 5ms/step
# Epoch 20/100
# 1174/1174 - 7s - loss: 0.5483 - accuracy: 0.7910 - 7s/epoch - 6ms/step
# Epoch 21/100
# 1174/1174 - 6s - loss: 0.5305 - accuracy: 0.7990 - 6s/epoch - 5ms/step
# Epoch 22/100
# 1174/1174 - 6s - loss: 0.5357 - accuracy: 0.7961 - 6s/epoch - 5ms/step
# Epoch 23/100
# 1174/1174 - 7s - loss: 0.5026 - accuracy: 0.8135 - 7s/epoch - 6ms/step
# Epoch 24/100
# 1174/1174 - 7s - loss: 0.5016 - accuracy: 0.8100 - 7s/epoch - 6ms/step
# Epoch 25/100
# 1174/1174 - 7s - loss: 0.4717 - accuracy: 0.8236 - 7s/epoch - 6ms/step
# Epoch 26/100
# 1174/1174 - 6s - loss: 0.4872 - accuracy: 0.8173 - 6s/epoch - 5ms/step
# Epoch 27/100
# 1174/1174 - 7s - loss: 0.4801 - accuracy: 0.8208 - 7s/epoch - 6ms/step
# Epoch 28/100
# 1174/1174 - 7s - loss: 0.4415 - accuracy: 0.8367 - 7s/epoch - 6ms/step
# Epoch 29/100
# 1174/1174 - 7s - loss: 0.4592 - accuracy: 0.8256 - 7s/epoch - 6ms/step
# Epoch 30/100
# 1174/1174 - 6s - loss: 0.4497 - accuracy: 0.8304 - 6s/epoch - 5ms/step
# Epoch 31/100
# 1174/1174 - 7s - loss: 0.4306 - accuracy: 0.8382 - 7s/epoch - 6ms/step
# Epoch 32/100
# 1174/1174 - 6s - loss: 0.4124 - accuracy: 0.8440 - 6s/epoch - 5ms/step
# Epoch 33/100
# 1174/1174 - 8s - loss: 0.4346 - accuracy: 0.8390 - 8s/epoch - 7ms/step
# Epoch 34/100
# 1174/1174 - 6s - loss: 0.4233 - accuracy: 0.8418 - 6s/epoch - 5ms/step
# Epoch 35/100
# 1174/1174 - 7s - loss: 0.4011 - accuracy: 0.8485 - 7s/epoch - 6ms/step
# Epoch 36/100
# 1174/1174 - 6s - loss: 0.3984 - accuracy: 0.8512 - 6s/epoch - 5ms/step
# Epoch 37/100
# 1174/1174 - 8s - loss: 0.3936 - accuracy: 0.8539 - 8s/epoch - 6ms/step
# Epoch 38/100
# 1174/1174 - 6s - loss: 0.3979 - accuracy: 0.8527 - 6s/epoch - 5ms/step
# Epoch 39/100
# 1174/1174 - 7s - loss: 0.3814 - accuracy: 0.8584 - 7s/epoch - 6ms/step
# Epoch 40/100
# 1174/1174 - 6s - loss: 0.3851 - accuracy: 0.8537 - 6s/epoch - 5ms/step
# Epoch 41/100
# 1174/1174 - 7s - loss: 0.3525 - accuracy: 0.8691 - 7s/epoch - 6ms/step
# Epoch 42/100
# 1174/1174 - 6s - loss: 0.3894 - accuracy: 0.8567 - 6s/epoch - 5ms/step
# Epoch 43/100
# 1174/1174 - 8s - loss: 0.3714 - accuracy: 0.8639 - 8s/epoch - 6ms/step
# Epoch 44/100
# 1174/1174 - 6s - loss: 0.3604 - accuracy: 0.8666 - 6s/epoch - 5ms/step
# Epoch 45/100
# 1174/1174 - 7s - loss: 0.3556 - accuracy: 0.8688 - 7s/epoch - 6ms/step
# Epoch 46/100
# 1174/1174 - 6s - loss: 0.3663 - accuracy: 0.8668 - 6s/epoch - 5ms/step
# Epoch 47/100
# 1174/1174 - 7s - loss: 0.3404 - accuracy: 0.8736 - 7s/epoch - 6ms/step
# Epoch 48/100
# 1174/1174 - 6s - loss: 0.3311 - accuracy: 0.8762 - 6s/epoch - 5ms/step
# Epoch 49/100
# 1174/1174 - 7s - loss: 0.3429 - accuracy: 0.8743 - 7s/epoch - 6ms/step
# Epoch 50/100
# 1174/1174 - 6s - loss: 0.3417 - accuracy: 0.8760 - 6s/epoch - 5ms/step
# Epoch 51/100
# 1174/1174 - 7s - loss: 0.3566 - accuracy: 0.8679 - 7s/epoch - 6ms/step
# Epoch 52/100
# 1174/1174 - 6s - loss: 0.3044 - accuracy: 0.8858 - 6s/epoch - 5ms/step
# Epoch 53/100
# 1174/1174 - 7s - loss: 0.3271 - accuracy: 0.8800 - 7s/epoch - 6ms/step
# Epoch 54/100
# 1174/1174 - 6s - loss: 0.3341 - accuracy: 0.8785 - 6s/epoch - 5ms/step
# Epoch 55/100
# 1174/1174 - 7s - loss: 0.3206 - accuracy: 0.8832 - 7s/epoch - 6ms/step
# Epoch 56/100
# 1174/1174 - 6s - loss: 0.3241 - accuracy: 0.8788 - 6s/epoch - 5ms/step
# Epoch 57/100
# 1174/1174 - 7s - loss: 0.3028 - accuracy: 0.8887 - 7s/epoch - 6ms/step
# Epoch 58/100
# 1174/1174 - 6s - loss: 0.3334 - accuracy: 0.8795 - 6s/epoch - 5ms/step
# Epoch 59/100
# 1174/1174 - 6s - loss: 0.2961 - accuracy: 0.8912 - 6s/epoch - 5ms/step
# Epoch 60/100
# 1174/1174 - 7s - loss: 0.2990 - accuracy: 0.8928 - 7s/epoch - 6ms/step
# Epoch 61/100
# 1174/1174 - 6s - loss: 0.3189 - accuracy: 0.8836 - 6s/epoch - 5ms/step
# Epoch 62/100
# 1174/1174 - 7s - loss: 0.2954 - accuracy: 0.8918 - 7s/epoch - 6ms/step
# Epoch 63/100
# 1174/1174 - 6s - loss: 0.3142 - accuracy: 0.8849 - 6s/epoch - 5ms/step
# Epoch 64/100
# 1174/1174 - 7s - loss: 0.2965 - accuracy: 0.8934 - 7s/epoch - 6ms/step
# Epoch 65/100
# 1174/1174 - 6s - loss: 0.2872 - accuracy: 0.8945 - 6s/epoch - 5ms/step
# Epoch 66/100
# 1174/1174 - 7s - loss: 0.3268 - accuracy: 0.8799 - 7s/epoch - 6ms/step
# Epoch 67/100
# 1174/1174 - 6s - loss: 0.2644 - accuracy: 0.9040 - 6s/epoch - 5ms/step
# Epoch 68/100
# 1174/1174 - 7s - loss: 0.2911 - accuracy: 0.8954 - 7s/epoch - 6ms/step
# Epoch 69/100
# 1174/1174 - 6s - loss: 0.2865 - accuracy: 0.8985 - 6s/epoch - 5ms/step
# Epoch 70/100
# 1174/1174 - 7s - loss: 0.2846 - accuracy: 0.8996 - 7s/epoch - 6ms/step
# Epoch 71/100
# 1174/1174 - 6s - loss: 0.3021 - accuracy: 0.8938 - 6s/epoch - 5ms/step
# Epoch 72/100
# 1174/1174 - 7s - loss: 0.2772 - accuracy: 0.8997 - 7s/epoch - 6ms/step
# Epoch 73/100
# 1174/1174 - 7s - loss: 0.2828 - accuracy: 0.8986 - 7s/epoch - 6ms/step
# Epoch 74/100
# 1174/1174 - 9s - loss: 0.2490 - accuracy: 0.9099 - 9s/epoch - 8ms/step
# Epoch 75/100
# 1174/1174 - 6s - loss: 0.2989 - accuracy: 0.8943 - 6s/epoch - 5ms/step
# Epoch 76/100
# 1174/1174 - 7s - loss: 0.2485 - accuracy: 0.9098 - 7s/epoch - 6ms/step
# Epoch 77/100
# 1174/1174 - 6s - loss: 0.2959 - accuracy: 0.8954 - 6s/epoch - 5ms/step
# Epoch 78/100
# 1174/1174 - 8s - loss: 0.2651 - accuracy: 0.9052 - 8s/epoch - 7ms/step
# Epoch 79/100
# 1174/1174 - 6s - loss: 0.2751 - accuracy: 0.9011 - 6s/epoch - 5ms/step
# Epoch 80/100
# 1174/1174 - 7s - loss: 0.2566 - accuracy: 0.9088 - 7s/epoch - 6ms/step
# Epoch 81/100
# 1174/1174 - 6s - loss: 0.2450 - accuracy: 0.9133 - 6s/epoch - 5ms/step
# Epoch 82/100
# 1174/1174 - 7s - loss: 0.2552 - accuracy: 0.9099 - 7s/epoch - 6ms/step
# Epoch 83/100
# 1174/1174 - 6s - loss: 0.2934 - accuracy: 0.9022 - 6s/epoch - 5ms/step
# Epoch 84/100
# 1174/1174 - 7s - loss: 0.2548 - accuracy: 0.9092 - 7s/epoch - 6ms/step
# Epoch 85/100
# 1174/1174 - 6s - loss: 0.2740 - accuracy: 0.9032 - 6s/epoch - 5ms/step
# Epoch 86/100
# 1174/1174 - 7s - loss: 0.2390 - accuracy: 0.9141 - 7s/epoch - 6ms/step
# Epoch 87/100
# 1174/1174 - 6s - loss: 0.2425 - accuracy: 0.9136 - 6s/epoch - 5ms/step
# Epoch 88/100
# 1174/1174 - 7s - loss: 0.2495 - accuracy: 0.9101 - 7s/epoch - 6ms/step
# Epoch 89/100
# 1174/1174 - 6s - loss: 0.2618 - accuracy: 0.9128 - 6s/epoch - 5ms/step
# Epoch 90/100
# 1174/1174 - 7s - loss: 0.2391 - accuracy: 0.9143 - 7s/epoch - 6ms/step
# Epoch 91/100
# 1174/1174 - 6s - loss: 0.2283 - accuracy: 0.9173 - 6s/epoch - 5ms/step
# Epoch 92/100
# 1174/1174 - 7s - loss: 0.2572 - accuracy: 0.9093 - 7s/epoch - 6ms/step
# Epoch 93/100
# 1174/1174 - 6s - loss: 0.2540 - accuracy: 0.9149 - 6s/epoch - 5ms/step
# Epoch 94/100
# 1174/1174 - 7s - loss: 0.2334 - accuracy: 0.9179 - 7s/epoch - 6ms/step
# Epoch 95/100
# 1174/1174 - 6s - loss: 0.2493 - accuracy: 0.9142 - 6s/epoch - 5ms/step
# Epoch 96/100
# 1174/1174 - 7s - loss: 0.2391 - accuracy: 0.9130 - 7s/epoch - 6ms/step
# Epoch 97/100
# 1174/1174 - 6s - loss: 0.2572 - accuracy: 0.9128 - 6s/epoch - 6ms/step
# Epoch 98/100
# 1174/1174 - 7s - loss: 0.2073 - accuracy: 0.9264 - 7s/epoch - 6ms/step
# Epoch 99/100
# 1174/1174 - 6s - loss: 0.2537 - accuracy: 0.9103 - 6s/epoch - 5ms/step
# Epoch 100/100
# 1174/1174 - 6s - loss: 0.2237 - accuracy: 0.9195 - 6s/epoch - 5ms/step

# %%
# Evaluate the model using the training data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 294/294 - 1s - loss: 0.2497 - accuracy: 0.9231 - 938ms/epoch - 3ms/step
# Loss: 0.2497054487466812, Accuracy: 0.92308509349823

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
print(y_true)
print(y_pred)
# Out:
# 294/294 [==============================] - 1s 4ms/step
# [5 1 4 ... 2 6 0]
# [5 1 4 ... 2 6 0]

# %%
pred=model.predict(X_test)
pred
# Out:
# 294/294 [==============================] - 1s 3ms/step
# array([[4.90672390e-13, 1.81543335e-14, 1.41333503e-05, ...,
#         3.57794645e-03, 9.96124923e-01, 2.82973662e-04],
#        [3.97920339e-05, 9.98803616e-01, 4.10414126e-04, ...,
#         7.39287410e-04, 3.71600140e-10, 6.89273611e-06],
#        [0.00000000e+00, 0.00000000e+00, 1.75122750e-05, ...,
#         9.99982417e-01, 0.00000000e+00, 1.99191504e-14],
#        ...,
#        [2.26659813e-06, 1.17840795e-08, 5.47979355e-01, ...,
#         2.28621170e-01, 3.36675248e-18, 2.23397166e-01],
#        [2.87797316e-23, 2.40115953e-18, 3.31689116e-05, ...,
#         8.22595656e-02, 5.38257773e-35, 9.17707264e-01],
#        [9.98876750e-01, 6.41978113e-04, 5.49500328e-05, ...,
#         4.62545649e-05, 4.41390364e-27, 3.80153448e-04]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.99      0.99      0.99      1359
#          bcc       0.97      0.98      0.98      1318
#          bkl       0.84      0.90      0.87      1262
#           df       0.99      1.00      0.99      1351
#           nv       0.86      0.71      0.77      1374
#         vasc       1.00      0.98      0.99      1358
#          mel       0.82      0.90      0.86      1365
#
#     accuracy                           0.92      9387
#    macro avg       0.92      0.92      0.92      9387
# weighted avg       0.92      0.92      0.92      9387

# %%
# Grab just one data point to test with
# test = np.expand_dims(X_train[0], axis=0)
# test.shape

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationWithScalingFinalOptimisation.h5")

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationWithScalingFinalOptimisation.h5")
