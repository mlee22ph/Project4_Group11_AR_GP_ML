# %% [markdown]
# # **SkinCancerClasification - With Scaling and more Optimisations**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
# Sklearn scaling
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Use RandomOverSampler**

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
#x = np.array(x).reshape(-1,28,28,3)
print('After RandomOverSampler - Shape of X :',x.shape)
print('After RandomOverSampler - Shape of Y :',y.shape)
# Out:
# After RandomOverSampler - Shape of X : (46935, 2352)
# After RandomOverSampler - Shape of Y : (46935,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
# This process is often referred to as z-score normalization or standardization.
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (37548, 2352)
# Testing Shape: (9387, 2352)

# %% [markdown]
# ### **Scaling and Normalization**

# %%
# Next, we normalize our training data to be between 0 and 1
scaler = MinMaxScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### **Create Sequential Model**

# %% [markdown]
# **With 100 units and 50 epochs:**
#
# 294/294 - 1s - loss: 0.5935 - accuracy: 0.7836 - 912ms/epoch - 3ms/step
# Loss: 0.5934981107711792, Accuracy: 0.7836369276046753
#
# **With 100 units and 100 epochs:**
# 294/294 - 0s - loss: 0.3575 - accuracy: 0.8681 - 431ms/epoch - 1ms/step
# Loss: 0.35752636194229126, Accuracy: 0.8681154847145081

# %%
# Added another layer to make 4 layers in total
# Increased units 100
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add a third hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 256207 (1000.81 KB)
# Trainable params: 256207 (1000.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased epochs to 100
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 1174/1174 - 8s - loss: 1.6131 - accuracy: 0.3539 - 8s/epoch - 7ms/step
# Epoch 2/100
# 1174/1174 - 5s - loss: 1.3374 - accuracy: 0.4732 - 5s/epoch - 4ms/step
# Epoch 3/100
# 1174/1174 - 7s - loss: 1.2121 - accuracy: 0.5256 - 7s/epoch - 6ms/step
# Epoch 4/100
# 1174/1174 - 5s - loss: 1.1366 - accuracy: 0.5596 - 5s/epoch - 5ms/step
# Epoch 5/100
# 1174/1174 - 7s - loss: 1.0650 - accuracy: 0.5879 - 7s/epoch - 6ms/step
# Epoch 6/100
# 1174/1174 - 5s - loss: 1.0096 - accuracy: 0.6104 - 5s/epoch - 4ms/step
# Epoch 7/100
# 1174/1174 - 6s - loss: 0.9551 - accuracy: 0.6321 - 6s/epoch - 5ms/step
# Epoch 8/100
# 1174/1174 - 6s - loss: 0.8976 - accuracy: 0.6551 - 6s/epoch - 5ms/step
# Epoch 9/100
# 1174/1174 - 5s - loss: 0.8409 - accuracy: 0.6757 - 5s/epoch - 4ms/step
# Epoch 10/100
# 1174/1174 - 7s - loss: 0.8123 - accuracy: 0.6893 - 7s/epoch - 6ms/step
# Epoch 11/100
# 1174/1174 - 5s - loss: 0.7620 - accuracy: 0.7085 - 5s/epoch - 5ms/step
# Epoch 12/100
# 1174/1174 - 7s - loss: 0.7259 - accuracy: 0.7253 - 7s/epoch - 6ms/step
# Epoch 13/100
# 1174/1174 - 5s - loss: 0.6935 - accuracy: 0.7362 - 5s/epoch - 4ms/step
# Epoch 14/100
# 1174/1174 - 6s - loss: 0.6841 - accuracy: 0.7399 - 6s/epoch - 5ms/step
# Epoch 15/100
# 1174/1174 - 6s - loss: 0.6357 - accuracy: 0.7599 - 6s/epoch - 5ms/step
# Epoch 16/100
# 1174/1174 - 5s - loss: 0.6258 - accuracy: 0.7615 - 5s/epoch - 4ms/step
# Epoch 17/100
# 1174/1174 - 7s - loss: 0.6225 - accuracy: 0.7632 - 7s/epoch - 6ms/step
# Epoch 18/100
# 1174/1174 - 5s - loss: 0.5940 - accuracy: 0.7772 - 5s/epoch - 5ms/step
# Epoch 19/100
# 1174/1174 - 7s - loss: 0.5712 - accuracy: 0.7819 - 7s/epoch - 6ms/step
# Epoch 20/100
# 1174/1174 - 5s - loss: 0.5638 - accuracy: 0.7881 - 5s/epoch - 5ms/step
# Epoch 21/100
# 1174/1174 - 6s - loss: 0.5439 - accuracy: 0.7933 - 6s/epoch - 5ms/step
# Epoch 22/100
# 1174/1174 - 5s - loss: 0.5305 - accuracy: 0.7997 - 5s/epoch - 5ms/step
# Epoch 23/100
# 1174/1174 - 5s - loss: 0.5251 - accuracy: 0.8007 - 5s/epoch - 4ms/step
# Epoch 24/100
# 1174/1174 - 7s - loss: 0.5221 - accuracy: 0.8023 - 7s/epoch - 6ms/step
# Epoch 25/100
# 1174/1174 - 5s - loss: 0.4965 - accuracy: 0.8130 - 5s/epoch - 5ms/step
# Epoch 26/100
# 1174/1174 - 7s - loss: 0.4808 - accuracy: 0.8185 - 7s/epoch - 6ms/step
# Epoch 27/100
# 1174/1174 - 5s - loss: 0.4783 - accuracy: 0.8204 - 5s/epoch - 4ms/step
# Epoch 28/100
# 1174/1174 - 6s - loss: 0.4612 - accuracy: 0.8267 - 6s/epoch - 5ms/step
# Epoch 29/100
# 1174/1174 - 6s - loss: 0.4547 - accuracy: 0.8302 - 6s/epoch - 5ms/step
# Epoch 30/100
# 1174/1174 - 5s - loss: 0.4605 - accuracy: 0.8276 - 5s/epoch - 5ms/step
# Epoch 31/100
# 1174/1174 - 7s - loss: 0.4483 - accuracy: 0.8328 - 7s/epoch - 6ms/step
# Epoch 32/100
# 1174/1174 - 5s - loss: 0.4117 - accuracy: 0.8460 - 5s/epoch - 4ms/step
# Epoch 33/100
# 1174/1174 - 6s - loss: 0.4339 - accuracy: 0.8390 - 6s/epoch - 5ms/step
# Epoch 34/100
# 1174/1174 - 5s - loss: 0.4418 - accuracy: 0.8366 - 5s/epoch - 4ms/step
# Epoch 35/100
# 1174/1174 - 6s - loss: 0.4157 - accuracy: 0.8463 - 6s/epoch - 6ms/step
# Epoch 36/100
# 1174/1174 - 6s - loss: 0.4037 - accuracy: 0.8510 - 6s/epoch - 5ms/step
# Epoch 37/100
# 1174/1174 - 5s - loss: 0.4161 - accuracy: 0.8506 - 5s/epoch - 4ms/step
# Epoch 38/100
# 1174/1174 - 7s - loss: 0.4053 - accuracy: 0.8512 - 7s/epoch - 6ms/step
# Epoch 39/100
# 1174/1174 - 5s - loss: 0.4176 - accuracy: 0.8469 - 5s/epoch - 5ms/step
# Epoch 40/100
# 1174/1174 - 8s - loss: 0.3745 - accuracy: 0.8618 - 8s/epoch - 7ms/step
# Epoch 41/100
# 1174/1174 - 5s - loss: 0.3797 - accuracy: 0.8603 - 5s/epoch - 4ms/step
# Epoch 42/100
# 1174/1174 - 6s - loss: 0.3780 - accuracy: 0.8594 - 6s/epoch - 6ms/step
# Epoch 43/100
# 1174/1174 - 5s - loss: 0.3660 - accuracy: 0.8651 - 5s/epoch - 5ms/step
# Epoch 44/100
# 1174/1174 - 6s - loss: 0.3640 - accuracy: 0.8621 - 6s/epoch - 5ms/step
# Epoch 45/100
# 1174/1174 - 7s - loss: 0.3950 - accuracy: 0.8557 - 7s/epoch - 6ms/step
# Epoch 46/100
# 1174/1174 - 5s - loss: 0.3397 - accuracy: 0.8739 - 5s/epoch - 4ms/step
# Epoch 47/100
# 1174/1174 - 7s - loss: 0.3270 - accuracy: 0.8782 - 7s/epoch - 6ms/step
# Epoch 48/100
# 1174/1174 - 5s - loss: 0.3389 - accuracy: 0.8744 - 5s/epoch - 4ms/step
# Epoch 49/100
# 1174/1174 - 7s - loss: 0.3531 - accuracy: 0.8693 - 7s/epoch - 6ms/step
# Epoch 50/100
# 1174/1174 - 5s - loss: 0.3320 - accuracy: 0.8794 - 5s/epoch - 4ms/step
# Epoch 51/100
# 1174/1174 - 6s - loss: 0.3364 - accuracy: 0.8765 - 6s/epoch - 5ms/step
# Epoch 52/100
# 1174/1174 - 6s - loss: 0.3324 - accuracy: 0.8781 - 6s/epoch - 5ms/step
# Epoch 53/100
# 1174/1174 - 5s - loss: 0.3147 - accuracy: 0.8840 - 5s/epoch - 4ms/step
# Epoch 54/100
# 1174/1174 - 7s - loss: 0.3211 - accuracy: 0.8808 - 7s/epoch - 6ms/step
# Epoch 55/100
# 1174/1174 - 5s - loss: 0.3229 - accuracy: 0.8800 - 5s/epoch - 4ms/step
# Epoch 56/100
# 1174/1174 - 7s - loss: 0.3198 - accuracy: 0.8844 - 7s/epoch - 6ms/step
# Epoch 57/100
# 1174/1174 - 5s - loss: 0.3134 - accuracy: 0.8845 - 5s/epoch - 4ms/step
# Epoch 58/100
# 1174/1174 - 6s - loss: 0.2998 - accuracy: 0.8914 - 6s/epoch - 5ms/step
# Epoch 59/100
# 1174/1174 - 6s - loss: 0.3432 - accuracy: 0.8764 - 6s/epoch - 5ms/step
# Epoch 60/100
# 1174/1174 - 5s - loss: 0.2919 - accuracy: 0.8940 - 5s/epoch - 4ms/step
# Epoch 61/100
# 1174/1174 - 7s - loss: 0.3398 - accuracy: 0.8813 - 7s/epoch - 6ms/step
# Epoch 62/100
# 1174/1174 - 8s - loss: 0.2888 - accuracy: 0.8960 - 8s/epoch - 7ms/step
# Epoch 63/100
# 1174/1174 - 6s - loss: 0.2949 - accuracy: 0.8933 - 6s/epoch - 5ms/step
# Epoch 64/100
# 1174/1174 - 5s - loss: 0.2749 - accuracy: 0.8988 - 5s/epoch - 4ms/step
# Epoch 65/100
# 1174/1174 - 6s - loss: 0.3063 - accuracy: 0.8868 - 6s/epoch - 5ms/step
# Epoch 66/100
# 1174/1174 - 5s - loss: 0.3172 - accuracy: 0.8890 - 5s/epoch - 4ms/step
# Epoch 67/100
# 1174/1174 - 6s - loss: 0.2886 - accuracy: 0.8954 - 6s/epoch - 5ms/step
# Epoch 68/100
# 1174/1174 - 6s - loss: 0.2668 - accuracy: 0.9013 - 6s/epoch - 5ms/step
# Epoch 69/100
# 1174/1174 - 5s - loss: 0.2653 - accuracy: 0.9022 - 5s/epoch - 4ms/step
# Epoch 70/100
# 1174/1174 - 7s - loss: 0.2762 - accuracy: 0.8992 - 7s/epoch - 6ms/step
# Epoch 71/100
# 1174/1174 - 5s - loss: 0.2736 - accuracy: 0.8993 - 5s/epoch - 4ms/step
# Epoch 72/100
# 1174/1174 - 7s - loss: 0.2940 - accuracy: 0.8946 - 7s/epoch - 6ms/step
# Epoch 73/100
# 1174/1174 - 5s - loss: 0.2482 - accuracy: 0.9082 - 5s/epoch - 5ms/step
# Epoch 74/100
# 1174/1174 - 7s - loss: 0.2611 - accuracy: 0.9038 - 7s/epoch - 6ms/step
# Epoch 75/100
# 1174/1174 - 5s - loss: 0.2786 - accuracy: 0.9022 - 5s/epoch - 5ms/step
# Epoch 76/100
# 1174/1174 - 5s - loss: 0.2388 - accuracy: 0.9129 - 5s/epoch - 4ms/step
# Epoch 77/100
# 1174/1174 - 6s - loss: 0.2896 - accuracy: 0.8963 - 6s/epoch - 5ms/step
# Epoch 78/100
# 1174/1174 - 5s - loss: 0.2557 - accuracy: 0.9081 - 5s/epoch - 4ms/step
# Epoch 79/100
# 1174/1174 - 7s - loss: 0.2390 - accuracy: 0.9114 - 7s/epoch - 6ms/step
# Epoch 80/100
# 1174/1174 - 5s - loss: 0.2574 - accuracy: 0.9069 - 5s/epoch - 4ms/step
# Epoch 81/100
# 1174/1174 - 6s - loss: 0.2860 - accuracy: 0.8986 - 6s/epoch - 5ms/step
# Epoch 82/100
# 1174/1174 - 6s - loss: 0.2298 - accuracy: 0.9173 - 6s/epoch - 5ms/step
# Epoch 83/100
# 1174/1174 - 5s - loss: 0.2603 - accuracy: 0.9082 - 5s/epoch - 4ms/step
# Epoch 84/100
# 1174/1174 - 7s - loss: 0.2574 - accuracy: 0.9089 - 7s/epoch - 6ms/step
# Epoch 85/100
# 1174/1174 - 5s - loss: 0.2513 - accuracy: 0.9089 - 5s/epoch - 4ms/step
# Epoch 86/100
# 1174/1174 - 6s - loss: 0.2297 - accuracy: 0.9167 - 6s/epoch - 5ms/step
# Epoch 87/100
# 1174/1174 - 5s - loss: 0.2686 - accuracy: 0.9096 - 5s/epoch - 4ms/step
# Epoch 88/100
# 1174/1174 - 5s - loss: 0.2665 - accuracy: 0.9079 - 5s/epoch - 4ms/step
# Epoch 89/100
# 1174/1174 - 6s - loss: 0.2562 - accuracy: 0.9086 - 6s/epoch - 5ms/step
# Epoch 90/100
# 1174/1174 - 5s - loss: 0.2415 - accuracy: 0.9117 - 5s/epoch - 4ms/step
# Epoch 91/100
# 1174/1174 - 7s - loss: 0.2393 - accuracy: 0.9146 - 7s/epoch - 6ms/step
# Epoch 92/100
# 1174/1174 - 5s - loss: 0.2590 - accuracy: 0.9107 - 5s/epoch - 4ms/step
# Epoch 93/100
# 1174/1174 - 5s - loss: 0.2489 - accuracy: 0.9122 - 5s/epoch - 5ms/step
# Epoch 94/100
# 1174/1174 - 6s - loss: 0.2718 - accuracy: 0.9056 - 6s/epoch - 5ms/step
# Epoch 95/100
# 1174/1174 - 5s - loss: 0.2179 - accuracy: 0.9231 - 5s/epoch - 4ms/step
# Epoch 96/100
# 1174/1174 - 6s - loss: 0.2368 - accuracy: 0.9162 - 6s/epoch - 6ms/step
# Epoch 97/100
# 1174/1174 - 5s - loss: 0.2302 - accuracy: 0.9178 - 5s/epoch - 4ms/step
# Epoch 98/100
# 1174/1174 - 6s - loss: 0.2798 - accuracy: 0.9057 - 6s/epoch - 5ms/step
# Epoch 99/100
# 1174/1174 - 5s - loss: 0.2325 - accuracy: 0.9170 - 5s/epoch - 5ms/step
# Epoch 100/100
# 1174/1174 - 5s - loss: 0.2308 - accuracy: 0.9184 - 5s/epoch - 4ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 294/294 - 1s - loss: 0.2429 - accuracy: 0.9212 - 741ms/epoch - 3ms/step
# Loss: 0.24290108680725098, Accuracy: 0.9211675524711609

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
# Print result and prediction for side by side comparison
print(y_true)
print(y_pred)
# Out:
# 294/294 [==============================] - 1s 2ms/step
# [5 1 4 ... 2 6 0]
# [5 1 4 ... 2 6 0]

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.98      1.00      0.99      1359
#          bcc       0.96      0.96      0.96      1318
#          bkl       0.82      0.93      0.87      1262
#           df       0.99      1.00      1.00      1351
#           nv       0.85      0.69      0.76      1374
#         vasc       1.00      1.00      1.00      1358
#          mel       0.85      0.87      0.86      1365
#
#     accuracy                           0.92      9387
#    macro avg       0.92      0.92      0.92      9387
# weighted avg       0.92      0.92      0.92      9387

# %%
# Print confusion matrix
confusion_matrix(y_true, y_pred)
# Out:
# array([[1359,    0,    0,    0,    0,    0,    0],
#        [   3, 1268,   24,    0,   19,    0,    4],
#        [   6,    8, 1175,    0,   53,    0,   20],
#        [   0,    0,    0, 1351,    0,    0,    0],
#        [  17,   39,  155,   12,  952,    6,  193],
#        [   0,    0,    0,    0,    0, 1358,    0],
#        [   5,    2,   81,    1,   92,    0, 1184]])

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationWithScalingFinalOptimisation.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationWithScalingFinalOptimisation.h5")
