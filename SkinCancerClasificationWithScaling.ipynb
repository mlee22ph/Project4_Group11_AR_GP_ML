# %% [markdown]
# # **SkinCancerClasification - With Scaling**

# %% [markdown]
# ## **Import libraries, read dataset**

# %%
# Import our dependencies
import matplotlib.pyplot as plt
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
# Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
# Sklearn scaling
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
y = data['label']
x = data.drop(columns = ['label'])

# %%
tabular_data = pd.read_csv('https://mlee22ph.github.io/Project4_Group11_AR_GP_ML/Resources/HAM10000_metadata.csv')
tabular_data.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
tabular_data.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'),
           1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ## **Model Analysis and Prediction**

# %%
x.shape
# Out:
# (10015, 2352)

# %%
y.shape
# Out:
# (10015,)

# %% [markdown]
# ### **Use RandomOverSampler**

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
x = np.array(x).reshape(-1,28,28,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 28, 28, 3)

# %%
print('Shape of Y :',y.shape)
# Out:
# Shape of Y : (46935,)

# %% [markdown]
# ### **Standardization and Splitting Data**

# %%
x = (x-np.mean(x))/np.std(x)
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
X_train.shape
# Out:
# (37548, 28, 28, 3)

# %%
# We want to flatten our image of 28x28 pixels to a 1D array of 784 pixels
ndims = X_train.shape[1] * X_train.shape[2] * X_train.shape[3]
X_train = X_train.reshape(X_train.shape[0], ndims)
X_test = X_test.reshape(X_test.shape[0], ndims)
print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)
# Out:
# Training Shape: (37548, 2352)
# Testing Shape: (9387, 2352)

# %% [markdown]
# ### **Scaling and Normalization**

# %%
# Next, we normalize our training data to be between 0 and 1
scaler = MinMaxScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### **Create Sequential Model**

# %% [markdown]
# **With 64 units:**
#
# 294/294 - 1s - loss: 0.9814 - accuracy: 0.6068 - 926ms/epoch - 3ms/step
# Loss: 0.9813539981842041, Accuracy: 0.6067966222763062

# %%
# Increased units from previous try
num_classes = 100

# Create an empty sequential model
model = Sequential()
# Add the first layer where the input dimensions are the 784 pixel values
# We can also choose our activation function. `relu` is a common
model.add(Dense(num_classes, activation='relu', input_dim=X_train.shape[1]))
# Add a second hidden layer
model.add(Dense(num_classes, activation='relu'))
# Add our final output layer where the number of nodes
# corresponds to the number of y labels
model.add(Dense(7, activation='softmax'))

# %%
# We can summarize our model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               235300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 7)                 707
#
# =================================================================
# Total params: 246107 (961.36 KB)
# Trainable params: 246107 (961.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **Compile Model using sparse_categorical_crossentropy, meaning no need for One Hot Encoding**

# %%
# Sparse categorical cross-entropy is an extension of the categorical cross-entropy loss function that is used when the output labels are represented in a sparse matrix format.
# In a sparse matrix format, the labels are represented as a single index value rather than a one-hot encoded vector. This means that the labels are integers rather than vectors.
# Both categorical cross-entropy and sparse categorical cross-entropy have the same loss function as defined above. The only difference between the two is in how labels are defined.
# Hint: your output layer in this example is using software for logistic regression (categorical)
# If your output layer activation was `linear` then you may want to use `mse` for loss
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Increased epochs from previous try
# Fit (train) the model
history = model.fit(
    X_train,
    Y_train,
    epochs=50,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/50
# 1174/1174 - 7s - loss: 1.6572 - accuracy: 0.3344 - 7s/epoch - 6ms/step
# Epoch 2/50
# 1174/1174 - 7s - loss: 1.3861 - accuracy: 0.4541 - 7s/epoch - 6ms/step
# Epoch 3/50
# 1174/1174 - 5s - loss: 1.2587 - accuracy: 0.5111 - 5s/epoch - 5ms/step
# Epoch 4/50
# 1174/1174 - 7s - loss: 1.1766 - accuracy: 0.5426 - 7s/epoch - 6ms/step
# Epoch 5/50
# 1174/1174 - 5s - loss: 1.1321 - accuracy: 0.5627 - 5s/epoch - 5ms/step
# Epoch 6/50
# 1174/1174 - 5s - loss: 1.0781 - accuracy: 0.5827 - 5s/epoch - 4ms/step
# Epoch 7/50
# 1174/1174 - 7s - loss: 1.0348 - accuracy: 0.6002 - 7s/epoch - 6ms/step
# Epoch 8/50
# 1174/1174 - 5s - loss: 0.9963 - accuracy: 0.6163 - 5s/epoch - 4ms/step
# Epoch 9/50
# 1174/1174 - 7s - loss: 0.9582 - accuracy: 0.6324 - 7s/epoch - 6ms/step
# Epoch 10/50
# 1174/1174 - 6s - loss: 0.9311 - accuracy: 0.6436 - 6s/epoch - 5ms/step
# Epoch 11/50
# 1174/1174 - 6s - loss: 0.8948 - accuracy: 0.6597 - 6s/epoch - 5ms/step
# Epoch 12/50
# 1174/1174 - 6s - loss: 0.8665 - accuracy: 0.6683 - 6s/epoch - 5ms/step
# Epoch 13/50
# 1174/1174 - 10s - loss: 0.8572 - accuracy: 0.6717 - 10s/epoch - 9ms/step
# Epoch 14/50
# 1174/1174 - 5s - loss: 0.8258 - accuracy: 0.6853 - 5s/epoch - 4ms/step
# Epoch 15/50
# 1174/1174 - 6s - loss: 0.8009 - accuracy: 0.6950 - 6s/epoch - 5ms/step
# Epoch 16/50
# 1174/1174 - 6s - loss: 0.7756 - accuracy: 0.7042 - 6s/epoch - 5ms/step
# Epoch 17/50
# 1174/1174 - 5s - loss: 0.7727 - accuracy: 0.7055 - 5s/epoch - 4ms/step
# Epoch 18/50
# 1174/1174 - 7s - loss: 0.7514 - accuracy: 0.7152 - 7s/epoch - 6ms/step
# Epoch 19/50
# 1174/1174 - 5s - loss: 0.7333 - accuracy: 0.7212 - 5s/epoch - 5ms/step
# Epoch 20/50
# 1174/1174 - 7s - loss: 0.7172 - accuracy: 0.7265 - 7s/epoch - 6ms/step
# Epoch 21/50
# 1174/1174 - 5s - loss: 0.7024 - accuracy: 0.7345 - 5s/epoch - 5ms/step
# Epoch 22/50
# 1174/1174 - 6s - loss: 0.6814 - accuracy: 0.7425 - 6s/epoch - 5ms/step
# Epoch 23/50
# 1174/1174 - 5s - loss: 0.6747 - accuracy: 0.7447 - 5s/epoch - 4ms/step
# Epoch 24/50
# 1174/1174 - 5s - loss: 0.6640 - accuracy: 0.7487 - 5s/epoch - 5ms/step
# Epoch 25/50
# 1174/1174 - 6s - loss: 0.6787 - accuracy: 0.7426 - 6s/epoch - 5ms/step
# Epoch 26/50
# 1174/1174 - 5s - loss: 0.6513 - accuracy: 0.7529 - 5s/epoch - 4ms/step
# Epoch 27/50
# 1174/1174 - 6s - loss: 0.6460 - accuracy: 0.7547 - 6s/epoch - 5ms/step
# Epoch 28/50
# 1174/1174 - 5s - loss: 0.6257 - accuracy: 0.7645 - 5s/epoch - 4ms/step
# Epoch 29/50
# 1174/1174 - 6s - loss: 0.6290 - accuracy: 0.7608 - 6s/epoch - 5ms/step
# Epoch 30/50
# 1174/1174 - 6s - loss: 0.6119 - accuracy: 0.7698 - 6s/epoch - 5ms/step
# Epoch 31/50
# 1174/1174 - 5s - loss: 0.6164 - accuracy: 0.7691 - 5s/epoch - 4ms/step
# Epoch 32/50
# 1174/1174 - 6s - loss: 0.6093 - accuracy: 0.7711 - 6s/epoch - 5ms/step
# Epoch 33/50
# 1174/1174 - 4s - loss: 0.5925 - accuracy: 0.7765 - 4s/epoch - 4ms/step
# Epoch 34/50
# 1174/1174 - 6s - loss: 0.5825 - accuracy: 0.7811 - 6s/epoch - 5ms/step
# Epoch 35/50
# 1174/1174 - 5s - loss: 0.5974 - accuracy: 0.7772 - 5s/epoch - 4ms/step
# Epoch 36/50
# 1174/1174 - 5s - loss: 0.5580 - accuracy: 0.7904 - 5s/epoch - 5ms/step
# Epoch 37/50
# 1174/1174 - 7s - loss: 0.5672 - accuracy: 0.7868 - 7s/epoch - 6ms/step
# Epoch 38/50
# 1174/1174 - 5s - loss: 0.5598 - accuracy: 0.7906 - 5s/epoch - 4ms/step
# Epoch 39/50
# 1174/1174 - 6s - loss: 0.5609 - accuracy: 0.7897 - 6s/epoch - 5ms/step
# Epoch 40/50
# 1174/1174 - 5s - loss: 0.5579 - accuracy: 0.7932 - 5s/epoch - 4ms/step
# Epoch 41/50
# 1174/1174 - 5s - loss: 0.5386 - accuracy: 0.7986 - 5s/epoch - 5ms/step
# Epoch 42/50
# 1174/1174 - 5s - loss: 0.5237 - accuracy: 0.8043 - 5s/epoch - 4ms/step
# Epoch 43/50
# 1174/1174 - 5s - loss: 0.5357 - accuracy: 0.7980 - 5s/epoch - 4ms/step
# Epoch 44/50
# 1174/1174 - 6s - loss: 0.5277 - accuracy: 0.8035 - 6s/epoch - 5ms/step
# Epoch 45/50
# 1174/1174 - 5s - loss: 0.5178 - accuracy: 0.8040 - 5s/epoch - 4ms/step
# Epoch 46/50
# 1174/1174 - 5s - loss: 0.5138 - accuracy: 0.8069 - 5s/epoch - 5ms/step
# Epoch 47/50
# 1174/1174 - 5s - loss: 0.5076 - accuracy: 0.8092 - 5s/epoch - 4ms/step
# Epoch 48/50
# 1174/1174 - 5s - loss: 0.5457 - accuracy: 0.7990 - 5s/epoch - 4ms/step
# Epoch 49/50
# 1174/1174 - 6s - loss: 0.4885 - accuracy: 0.8179 - 6s/epoch - 5ms/step
# Epoch 50/50
# 1174/1174 - 5s - loss: 0.4923 - accuracy: 0.8168 - 5s/epoch - 4ms/step

# %%
# Evaluate the model using the training data
model_loss, model_accuracy = model.evaluate(X_test, Y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 294/294 - 1s - loss: 0.5437 - accuracy: 0.8009 - 690ms/epoch - 2ms/step
# Loss: 0.54367995262146, Accuracy: 0.8008948564529419

# %% [markdown]
# ## **Making Predictions and Classification Report**

# %%
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
y_true = np.array(Y_test)
y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))
print(y_true)
print(y_pred)
# Out:
# 294/294 [==============================] - 1s 3ms/step
# [5 1 4 ... 2 6 0]
# [5 3 4 ... 2 6 0]

# %%
pred=model.predict(X_test)
pred
# Out:
# 294/294 [==============================] - 1s 2ms/step
# array([[7.03874797e-16, 1.12857946e-04, 5.99727628e-07, ...,
#         4.17113688e-06, 9.99881327e-01, 9.54033226e-07],
#        [2.64778174e-03, 3.45388144e-01, 1.09466845e-02, ...,
#         3.88676091e-03, 1.51634868e-05, 1.92197170e-02],
#        [2.27885448e-15, 7.17794617e-12, 6.11775406e-02, ...,
#         9.35314953e-01, 2.32207285e-15, 3.50747793e-03],
#        ...,
#        [1.24872861e-06, 1.62403121e-05, 7.73588121e-01, ...,
#         1.25712290e-01, 1.41604631e-10, 3.40004521e-03],
#        [2.61227955e-17, 5.04986656e-06, 1.31911352e-01, ...,
#         1.04567565e-01, 1.02132489e-27, 7.63516068e-01],
#        [6.93518221e-01, 5.62861143e-03, 1.60395667e-01, ...,
#         1.09998789e-02, 9.71049644e-07, 5.45548126e-02]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix , classification_report

target_names = ["akiec", "bcc", "bkl", "df", "nv", "vasc", "mel"]
report = classification_report(y_true, y_pred, target_names=target_names)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        akiec       0.94      0.81      0.87      1359
#          bcc       0.91      0.72      0.80      1318
#          bkl       0.51      0.82      0.63      1262
#           df       0.95      0.99      0.97      1351
#           nv       0.78      0.62      0.69      1374
#         vasc       1.00      0.99      0.99      1358
#          mel       0.70      0.66      0.68      1365
#
#     accuracy                           0.80      9387
#    macro avg       0.83      0.80      0.80      9387
# weighted avg       0.83      0.80      0.81      9387

# %%
# Grab just one data point to test with
test = np.expand_dims(X_train[0], axis=0)
test.shape
# Out:
# (1, 2352)

# %% [markdown]
# ## **Saving and Loading models**

# %%
# Save the model
model.save("SkinCancerClasificationWithScaling.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("SkinCancerClasificationWithScaling.h5")
